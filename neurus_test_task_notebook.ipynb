# %%
import os
import random
import time
import copy
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from time import sleep

import torch
import cv2
import timm
from torch import nn, optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from catalyst.data.sampler import BalanceClassSampler
from ranger import Ranger
#https://github.com/lessw2020/Ranger-Deep-Learning-Optimizer
import torch.nn.functional as F
from torch.cuda.amp import autocast, GradScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
import albumentations as A
from albumentations import (
    HorizontalFlip, VerticalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine, RandomResizedCrop,
    IAASharpen, IAAEmboss, RandomBrightnessContrast, Flip, OneOf, Compose, Normalize, Cutout, ShiftScaleRotate, CenterCrop, Resize
)
from albumentations.pytorch import ToTensorV2

import logging
logging.getLogger().setLevel(logging.INFO)

import warnings
warnings.filterwarnings('ignore')

# %%
# seed everything
SEED = 55555

random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# hyperparameters
DATA_PATH = r"./data/train/"
TEST_DATA_PATH = r"./data/valid/"

IMAGE_SIZE = 300
BATCH_SIZE = 16
GRADIENT_ACCUMULATION_STEPS = 5
LEARNING_RATE = 0.0005
EPOCHS = 100
N_CLASS = 2
LAMBDA = 30

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    logging.info(f"Running on {torch.cuda.get_device_name()}")
else:
    device = torch.device("cpu")
    logging.info("Running on a CPU")
# Out:
# INFO:root:Running on GeForce GTX 1060 6GB

# %%
def get_train_test_valid_dataloaders(data_path, test_data_path, seed, image_size, batch_size):
    """
    Utility function for the model.
    """
    def build_data(data_path):
        content_list = []
        labels_list = []

        for image in tqdm_notebook(os.listdir(data_path)):
            if ".jpg" in image:
                content = cv2.imread(data_path + image)
                content_list.append(content)
            elif ".txt" in image:
                with open(data_path + image, "r") as f:
                    labels = f.read()
                labels = np.array(labels.split(" "), dtype=int)
                labels[0] = 0 if labels[0] == 1 else 1
                labels = np.roll(labels, -1)
                labels_list.append(labels)
        data = np.array([list(a) for a in zip(content_list, labels_list)])

        return data

    train_data = build_data(data_path=data_path)
    test_data = build_data(data_path=test_data_path)

    train_data, valid_data = train_test_split(train_data, shuffle=True, test_size=0.1, random_state=seed)

    train_clf_labels = [a[-1] for a in train_data[:, 1]]

    transform = Compose(
        [
            Resize(width=image_size, height=image_size),
            HorizontalFlip(p=0.4),
            # ShiftScaleRotate(p=0.3),
            MedianBlur(blur_limit=7, always_apply=False, p=0.3),
            IAAAdditiveGaussianNoise(scale=(0, 0.15 * 255), p=0.5),
            HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.4),
            RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), p=0.5),
            # in this implementation imagenet normalization is used
            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, p=1.0),
            Cutout(p=0.4),
            ToTensorV2(p=1.0),
        ],
        p=1.0,
        bbox_params=A.BboxParams(format="pascal_voc"),
    )

    test_transform = Compose(
        [
            # only resize and normalization is used for testing
            # no TTA is implemented in this solution
            Resize(width=image_size, height=image_size),
            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, p=1.0),
            ToTensorV2(p=1.0),
        ],
        p=1.0,
        bbox_params=A.BboxParams(format="pascal_voc"),
    )

    train_dataset = Dataset(train_data, transforms=transform)
    valid_dataset = Dataset(valid_data, transforms=transform)
    test_dataset = Dataset(test_data, transforms=test_transform)

    train_dataloader = DataLoader(
        train_dataset,
        # balanced sampler is used to minimize harmful effects of dataset not being fully balanced
        sampler=BalanceClassSampler(labels=train_clf_labels, mode="upsampling"),
        batch_size=batch_size,
    )
    test_dataloader = DataLoader(test_dataset, sampler=SequentialSampler(test_dataset), batch_size=1)
    valid_dataloader = DataLoader(valid_dataset, sampler=SequentialSampler(valid_dataset), batch_size=batch_size)

    return train_dataloader, test_dataloader, valid_dataloader

# %%
# custom dataset class that augments data during training
# imagenet normalization is used for efficientnet fine-tuning

class Dataset(torch.utils.data.Dataset):
    def __init__(self, dataset, transforms=None):
        super().__init__()
        self.data = dataset
        self.transforms = transforms

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        image, label = self.data[index][0], self.data[index][1]
        if image.shape[-1] == 4:
            # removing alpha channel if present
            image = image[..., :3]
        if len(image.shape) == 2:
            # converting single channel image to 3 channel for possible greyscales
            image = np.stack((image,)  * 3, axis = -1)

        if self.transforms is not None:
            # bboxes=[labels] labels are wrapped into list for correct augmentation
            transformed = self.transforms(image=image, bboxes=[label])

            image = transformed["image"]
            label = torch.Tensor(transformed["bboxes"])[0]

        return image, label

transform = Compose([
            Resize(width=IMAGE_SIZE, height=IMAGE_SIZE),
            HorizontalFlip(p=0.4),
            ShiftScaleRotate(p=0.3),
            MedianBlur(blur_limit=7, always_apply=False, p=0.3),
            IAAAdditiveGaussianNoise(scale=(0, 0.15*255), p=0.5),
            HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.4),
            RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), p=0.5),
            # in this implementation imagenet normalization is used            
            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, p=1.0),
            Cutout(p=0.4),
            ToTensorV2(p=1.0),
        ], p=1.0, bbox_params=A.BboxParams(format='pascal_voc'))

test_transform = Compose([
            # only resize and normalization is used for testing
            # no TTA is implemented in this solution
            Resize(width=IMAGE_SIZE, height=IMAGE_SIZE),                    
            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, p=1.0),
            ToTensorV2(p=1.0),
        ], p=1.0, bbox_params=A.BboxParams(format='pascal_voc'))

# %%
train_dataloader, test_dataloader, valid_dataloader = get_train_test_valid_dataloaders(DATA_PATH,
                                                                                        TEST_DATA_PATH,
                                                                                        SEED,
                                                                                        IMAGE_SIZE,
                                                                                        BATCH_SIZE
                                                                                        )
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5970.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))

# %%
class EFN_Classifier(nn.Module):
    def __init__(self, model_arch, n_class, pretrained=True):
            super().__init__()
            self.model = timm.create_model(model_arch, pretrained=pretrained)
            n_features = self.model.classifier.in_features
            self.model.classifier = nn.Linear(n_features, 2048)

            self.fc1 = nn.Linear(2048, 1536)
            self.fc2 = nn.Linear(2048, 512)

            self.dropout = nn.Dropout(0.35)

            self.fc_bbox = nn.Linear(1536, 4)
            self.fc_clf = nn.Linear(512, n_class)

    def forward(self, x):
        x = self.model(x)
        x = self.dropout(x)

        x_bbox = self.fc1(x)
        x_bbox = self.dropout(x_bbox)

        x = self.fc2(x)
        x = self.dropout(x)

        x_bbox = self.fc_bbox(x_bbox)
        x = self.fc_clf(x)

        return x, x_bbox

net = EFN_Classifier("tf_efficientnet_b1_ns", N_CLASS).to(device)
# EfficientNet: https://arxiv.org/abs/1905.11946
# fine tuning the efficientnet for classification and object detection
# in this implementation, no weights are frozen
# ideally, batchnorm layers can be frozen for marginal training speed increase

# %%
# class EFN_Simple_Classifier(nn.Module):
#     def __init__(self, n_class):
#         super(EFN_Simple_Classifier, self).__init__()
#         self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=2, padding=0)
#         self.bn1 = nn.BatchNorm2d(32)
#         self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=2)
#         self.bn2 = nn.BatchNorm2d(64)
#         self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, padding=2)
#         self.bn3 = nn.BatchNorm2d(128)
#         self.conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=5, padding=2)
#         self.bn4 = nn.BatchNorm2d(256)
#         self.conv5 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=5, padding=2)
#         self.bn5 = nn.BatchNorm2d(512)
#         self.conv6 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=5, padding=2)
#         self.bn6 = nn.BatchNorm2d(1024)
#         self.conv7 = nn.Conv2d(in_channels=1024, out_channels=2048, kernel_size=5, padding=2)
#         self.bn7 = nn.BatchNorm2d(2048)

#         self.pool = nn.AvgPool2d(2)

#         self.fc1 = nn.Linear(2048, 2048)

#         self.dropout = nn.Dropout(0.15)

#         self.fc_bbox = nn.Linear(2048, 4)
#         self.fc_clf = nn.Linear(2048, n_class)

#     def mish(self, x):
#         return x * torch.tanh(F.softplus(x))
        
#     def forward(self, x):

#         x = self.pool(self.mish(self.bn1(self.conv1(x)))) 
#         x = self.dropout(self.pool(self.mish(self.bn2(self.conv2(x)))))
#         x = self.dropout(self.pool(self.mish(self.bn3(self.conv3(x)))))
#         x = self.dropout(self.pool(self.mish(self.bn4(self.conv4(x)))))
#         x = self.dropout(self.pool(self.mish(self.bn5(self.conv5(x)))))
#         x = self.dropout(self.pool(self.mish(self.bn6(self.conv6(x)))))
#         x = self.dropout(self.pool(self.mish(self.bn7(self.conv7(x)))))
#         x = torch.flatten(x, 1)
#         x_clf = self.fc_clf(x)
#         x_bbox = self.fc1(x)
#         x_bbox = self.fc_bbox(x_bbox)

#         return x_clf, x_bbox

# net = EFN_Simple_Classifier(N_CLASS).to(device)
# simple neural network with considerably worse performance than efficientnet-based net

# %%
loss_function = nn.MSELoss()
clf_loss_function = nn.CrossEntropyLoss()
optimizer = Ranger(net.parameters(), lr=LEARNING_RATE, weight_decay = 0.999, betas = (0.9, 0.999))
scheduler = CosineAnnealingLR(optimizer, EPOCHS * 0.50, LEARNING_RATE * 0.0001)
scheduler.last_epoch = EPOCHS
scaler = GradScaler()

def training_loop():
    best_model_wts = copy.deepcopy(net.state_dict())
    best_loss = float("inf")
    
    for epoch in (range(EPOCHS)):        
        if epoch != 0 and epoch > 0.50 * EPOCHS: # cosine anneal the last 25% of epochs
            scheduler.step()
        logging.info(f"Epoch {epoch+1}")

        logging.info("Training")
        train_losses, train_accuracies, train_miou = forward_pass(train_dataloader, train = True)  

        logging.info("Validating")
        val_losses, val_accuracies, val_miou = forward_pass(valid_dataloader)

        logging.info(
                f"Training accuracy: {sum(train_accuracies)/len(train_accuracies):.2f}"
                f" | Training loss: {sum(train_losses)/len(train_losses):.2f}"
                f" | Training mIoU: {sum(train_miou)/len(train_miou):.2f}"
            )
        logging.info(
                f"Validation accuracy: {sum(val_accuracies)/len(val_accuracies):.2f}"
                f" | Validation loss: {sum(val_losses)/len(val_losses):.2f}"
                f" | Validation mIoU: {sum(val_miou)/len(val_miou):.2f}"
            )
        
        epoch_val_loss = sum(val_losses)/len(val_losses)
        
        if best_loss > epoch_val_loss:            
            best_model_wts = copy.deepcopy(net.state_dict())
            torch.save(net.state_dict(), "best.pth")
            logging.info(f"Saving with loss of {epoch_val_loss}, improved over previous {best_loss}")
            best_loss = epoch_val_loss
# Out:
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers

# %%
def bbox_iou(true_boxes, pred_boxes):
    iou_list = []    
    for true_box, pred_box in zip(true_boxes, pred_boxes):        

        x_left = max(true_box[0], pred_box[0]).item()
        y_top = max(true_box[1], pred_box[1]).item()

        x_right = min(true_box[2], pred_box[2]).item()
        y_bottom = min(true_box[3], pred_box[3]).item()

        if x_right < x_left or y_bottom < y_top:
            return 0.0 

        overlap = (x_right - x_left) * (y_bottom - y_top)

        true_box_area = (true_box[2] - true_box[0]) * (true_box[3] - true_box[1])
        pred_box_area = (pred_box[2] - pred_box[0]) * (pred_box[3] - pred_box[1])
        iou = overlap / float(true_box_area + pred_box_area - overlap)        
        iou_list.append(iou)
    
    iou = torch.tensor(iou)
    iou = torch.mean(iou)    

    return iou

def draw_boxes(images, bboxes, labels):        
        label_dict = {0 : "Cat", 1 : "Dog"}

        for batch in zip(images, bboxes, labels):
                cv2.destroyAllWindows()
                image, bbox, label = batch[0].cpu().numpy(), batch[1].cpu().numpy(), torch.argmax(batch[2]).cpu().item()
                image = np.rollaxis(image, 0, 3)
                image = ((image - image.min()) * (1/(image.max() - image.min()) * 255)).astype('uint8')
                image = cv2.UMat(image)

                cv2.rectangle(image,
                        (bbox[0], bbox[1]),
                        (bbox[2], bbox[3]),
                        (0, 255, 0),
                        thickness=2)

                cv2.putText(image, f"{label_dict[label]}", (bbox[1], bbox[3]), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)
                cv2.imshow("test", image)
                cv2.waitKey(1)
                sleep(1)        


def forward_pass(dataloader, draw=False, train=False):
    if train:
        net.train()
    else:
        net.eval()

    losses = []
    accuracies = []
    miou = []

    for step, batch in (enumerate(dataloader)):
        inputs = batch[0].to(device).float()
        labels = batch[1].to(device).float()
        
        # splitting labels for separate loss calculation
        bbox_labels = labels[:, :4] 
        clf_labels = labels[:, 4:].long()
        clf_labels = clf_labels[:,0]       

        with autocast():
            if train:
                label_outputs, bbox_outputs = net(inputs)
                bbox_loss = loss_function(bbox_outputs, bbox_labels)                
                clf_loss = clf_loss_function(label_outputs, clf_labels)

                loss = torch.mean(bbox_loss + clf_loss*LAMBDA)
                scaler.scale(loss).backward()
            else:
                with torch.no_grad():
                    label_outputs, bbox_outputs = net(inputs)
                    bbox_loss = loss_function(bbox_outputs, bbox_labels)                
                    clf_loss = clf_loss_function(label_outputs, clf_labels)
                    loss = torch.mean(bbox_loss + clf_loss*LAMBDA)
        if draw:
            draw_boxes(inputs, bbox_outputs, label_outputs)
        
        matches = [torch.argmax(i) == j for i, j in zip(label_outputs, clf_labels)] 
        acc = matches.count(True)/len(matches)
        iou = bbox_iou(bbox_labels, bbox_outputs)

        miou.append(iou)
        losses.append(loss)
        accuracies.append(acc)
        
        if train and (step+1) % GRADIENT_ACCUMULATION_STEPS == 0:
        # gradient accumulation to train with bigger effective batch size 
        # with less memory use
        # fp16 is used to speed up training and reduce memory consumption
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()            
            logging.info(f"Step {step} of {len(train_dataloader)},\t"\
                            f"Accuracy: {sum(accuracies)/len(accuracies):.2f},\t"\
                            f"mIoU: {sum(miou)/len(miou):.2f},\t"\
                            f"Loss: {sum(losses)/len(losses):.2f}")

    return losses, accuracies, miou

# %%
training_loop()
# Out:
# INFO:root:Epoch 1
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.51,	mIoU: 0.00,	Loss: 23267.00
# INFO:root:Step 9 of 233,	Accuracy: 0.49,	mIoU: 0.00,	Loss: 23321.40
# INFO:root:Step 14 of 233,	Accuracy: 0.53,	mIoU: 0.00,	Loss: 22933.61
# INFO:root:Step 19 of 233,	Accuracy: 0.50,	mIoU: 0.00,	Loss: 23194.31
# INFO:root:Step 24 of 233,	Accuracy: 0.49,	mIoU: 0.00,	Loss: 23347.45
# INFO:root:Step 29 of 233,	Accuracy: 0.49,	mIoU: 0.00,	Loss: 23425.36
# INFO:root:Step 34 of 233,	Accuracy: 0.48,	mIoU: 0.00,	Loss: 23792.48
# INFO:root:Step 39 of 233,	Accuracy: 0.47,	mIoU: 0.00,	Loss: 23771.54
# INFO:root:Step 44 of 233,	Accuracy: 0.48,	mIoU: 0.00,	Loss: 23510.00
# INFO:root:Step 49 of 233,	Accuracy: 0.48,	mIoU: 0.00,	Loss: 23447.42
# INFO:root:Step 54 of 233,	Accuracy: 0.49,	mIoU: 0.00,	Loss: 23177.58
# INFO:root:Step 59 of 233,	Accuracy: 0.49,	mIoU: 0.00,	Loss: 22920.27
# INFO:root:Step 64 of 233,	Accuracy: 0.50,	mIoU: 0.00,	Loss: 22839.80
# INFO:root:Step 69 of 233,	Accuracy: 0.50,	mIoU: 0.00,	Loss: 22195.32
# INFO:root:Step 74 of 233,	Accuracy: 0.50,	mIoU: 0.00,	Loss: 21597.00
# INFO:root:Step 79 of 233,	Accuracy: 0.50,	mIoU: 0.00,	Loss: 21158.67
# INFO:root:Step 84 of 233,	Accuracy: 0.51,	mIoU: 0.00,	Loss: 21188.34
# INFO:root:Step 89 of 233,	Accuracy: 0.51,	mIoU: 0.00,	Loss: 21322.00
# INFO:root:Step 94 of 233,	Accuracy: 0.51,	mIoU: 0.00,	Loss: 21518.42
# INFO:root:Step 99 of 233,	Accuracy: 0.51,	mIoU: 0.00,	Loss: 21634.60
# INFO:root:Step 104 of 233,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 21260.93
# INFO:root:Step 109 of 233,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 20890.26
# INFO:root:Step 114 of 233,	Accuracy: 0.53,	mIoU: 0.00,	Loss: 20517.55
# INFO:root:Step 119 of 233,	Accuracy: 0.54,	mIoU: 0.00,	Loss: 20226.19
# INFO:root:Step 124 of 233,	Accuracy: 0.54,	mIoU: 0.00,	Loss: 19945.05
# INFO:root:Step 129 of 233,	Accuracy: 0.54,	mIoU: 0.00,	Loss: 19671.20
# INFO:root:Step 134 of 233,	Accuracy: 0.54,	mIoU: 0.00,	Loss: 19417.90
# INFO:root:Step 139 of 233,	Accuracy: 0.55,	mIoU: 0.00,	Loss: 19182.41
# INFO:root:Step 144 of 233,	Accuracy: 0.55,	mIoU: 0.00,	Loss: 18998.57
# INFO:root:Step 149 of 233,	Accuracy: 0.56,	mIoU: 0.00,	Loss: 18804.05
# INFO:root:Step 154 of 233,	Accuracy: 0.56,	mIoU: 0.00,	Loss: 18582.21
# INFO:root:Step 159 of 233,	Accuracy: 0.57,	mIoU: 0.00,	Loss: 18437.16
# INFO:root:Step 164 of 233,	Accuracy: 0.57,	mIoU: 0.00,	Loss: 18234.26
# INFO:root:Step 169 of 233,	Accuracy: 0.58,	mIoU: 0.00,	Loss: 18061.92
# INFO:root:Step 174 of 233,	Accuracy: 0.58,	mIoU: 0.00,	Loss: 17884.62
# INFO:root:Step 179 of 233,	Accuracy: 0.59,	mIoU: 0.00,	Loss: 17698.80
# INFO:root:Step 184 of 233,	Accuracy: 0.59,	mIoU: 0.00,	Loss: 17538.41
# INFO:root:Step 189 of 233,	Accuracy: 0.60,	mIoU: 0.00,	Loss: 17381.45
# INFO:root:Step 194 of 233,	Accuracy: 0.60,	mIoU: 0.00,	Loss: 17238.38
# INFO:root:Step 199 of 233,	Accuracy: 0.60,	mIoU: 0.00,	Loss: 17130.29
# INFO:root:Step 204 of 233,	Accuracy: 0.61,	mIoU: 0.00,	Loss: 17004.32
# INFO:root:Step 209 of 233,	Accuracy: 0.61,	mIoU: 0.00,	Loss: 16885.72
# INFO:root:Step 214 of 233,	Accuracy: 0.61,	mIoU: 0.00,	Loss: 16716.38
# INFO:root:Step 219 of 233,	Accuracy: 0.62,	mIoU: 0.00,	Loss: 16568.53
# INFO:root:Step 224 of 233,	Accuracy: 0.62,	mIoU: 0.00,	Loss: 16453.49
# INFO:root:Step 229 of 233,	Accuracy: 0.62,	mIoU: 0.00,	Loss: 16340.56
# INFO:root:Validating
# INFO:root:Training accuracy: 0.62 | Training loss: 16258.68 | Training mIoU: 0.00
# INFO:root:Validation accuracy: 0.83 | Validation loss: 11815.70 | Validation mIoU: 0.00
# INFO:root:Saving with loss of 11815.6953125, improved over previous inf
# INFO:root:Epoch 2
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 10212.47
# INFO:root:Step 9 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 10027.40
# INFO:root:Step 14 of 233,	Accuracy: 0.82,	mIoU: 0.00,	Loss: 9706.19
# INFO:root:Step 19 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 9557.79
# INFO:root:Step 24 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 9822.62
# INFO:root:Step 29 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 9889.96
# INFO:root:Step 34 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 9738.80
# INFO:root:Step 39 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 9463.03
# INFO:root:Step 44 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 9429.53
# INFO:root:Step 49 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 9306.89
# INFO:root:Step 54 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 9165.69
# INFO:root:Step 59 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 9011.65
# INFO:root:Step 64 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 8874.64
# INFO:root:Step 69 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 8741.59
# INFO:root:Step 74 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 8555.62
# INFO:root:Step 79 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 8334.06
# INFO:root:Step 84 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 8213.69
# INFO:root:Step 89 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 8058.02
# INFO:root:Step 94 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 7912.30
# INFO:root:Step 99 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 7737.95
# INFO:root:Step 104 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 7562.81
# INFO:root:Step 109 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 7385.78
# INFO:root:Step 114 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 7286.00
# INFO:root:Step 119 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 7142.94
# INFO:root:Step 124 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 6996.92
# INFO:root:Step 129 of 233,	Accuracy: 0.80,	mIoU: 0.00,	Loss: 6872.80
# INFO:root:Step 134 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 6731.22
# INFO:root:Step 139 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 6585.01
# INFO:root:Step 144 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 6475.45
# INFO:root:Step 149 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 6346.58
# INFO:root:Step 154 of 233,	Accuracy: 0.81,	mIoU: 0.00,	Loss: 6221.96
# INFO:root:Step 159 of 233,	Accuracy: 0.81,	mIoU: 0.01,	Loss: 6102.92
# INFO:root:Step 164 of 233,	Accuracy: 0.81,	mIoU: 0.01,	Loss: 5984.90
# INFO:root:Step 169 of 233,	Accuracy: 0.81,	mIoU: 0.02,	Loss: 5872.18
# INFO:root:Step 174 of 233,	Accuracy: 0.81,	mIoU: 0.02,	Loss: 5788.51
# INFO:root:Step 179 of 233,	Accuracy: 0.81,	mIoU: 0.02,	Loss: 5687.79
# INFO:root:Step 184 of 233,	Accuracy: 0.80,	mIoU: 0.02,	Loss: 5591.64
# INFO:root:Step 189 of 233,	Accuracy: 0.80,	mIoU: 0.03,	Loss: 5496.74
# INFO:root:Step 194 of 233,	Accuracy: 0.80,	mIoU: 0.03,	Loss: 5411.58
# INFO:root:Step 199 of 233,	Accuracy: 0.80,	mIoU: 0.03,	Loss: 5333.32
# INFO:root:Step 204 of 233,	Accuracy: 0.80,	mIoU: 0.04,	Loss: 5252.04
# INFO:root:Step 209 of 233,	Accuracy: 0.80,	mIoU: 0.04,	Loss: 5170.74
# INFO:root:Step 214 of 233,	Accuracy: 0.80,	mIoU: 0.04,	Loss: 5101.47
# INFO:root:Step 219 of 233,	Accuracy: 0.80,	mIoU: 0.04,	Loss: 5030.46
# INFO:root:Step 224 of 233,	Accuracy: 0.80,	mIoU: 0.05,	Loss: 4973.31
# INFO:root:Step 229 of 233,	Accuracy: 0.80,	mIoU: 0.05,	Loss: 4908.32
# INFO:root:Validating
# INFO:root:Training accuracy: 0.80 | Training loss: 4874.40 | Training mIoU: 0.06
# INFO:root:Validation accuracy: 0.90 | Validation loss: 2167.76 | Validation mIoU: 0.15
# INFO:root:Saving with loss of 2167.75830078125, improved over previous 11815.6953125
# INFO:root:Epoch 3
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.86,	mIoU: 0.19,	Loss: 1881.78
# INFO:root:Step 9 of 233,	Accuracy: 0.85,	mIoU: 0.19,	Loss: 2100.99
# INFO:root:Step 14 of 233,	Accuracy: 0.83,	mIoU: 0.16,	Loss: 2105.18
# INFO:root:Step 19 of 233,	Accuracy: 0.83,	mIoU: 0.16,	Loss: 2054.97
# INFO:root:Step 24 of 233,	Accuracy: 0.83,	mIoU: 0.16,	Loss: 2024.68
# INFO:root:Step 29 of 233,	Accuracy: 0.83,	mIoU: 0.19,	Loss: 1958.01
# INFO:root:Step 34 of 233,	Accuracy: 0.83,	mIoU: 0.19,	Loss: 1964.79
# INFO:root:Step 39 of 233,	Accuracy: 0.81,	mIoU: 0.21,	Loss: 1942.88
# INFO:root:Step 44 of 233,	Accuracy: 0.81,	mIoU: 0.20,	Loss: 1959.08
# INFO:root:Step 49 of 233,	Accuracy: 0.80,	mIoU: 0.19,	Loss: 1961.21
# INFO:root:Step 54 of 233,	Accuracy: 0.80,	mIoU: 0.19,	Loss: 1961.88
# INFO:root:Step 59 of 233,	Accuracy: 0.80,	mIoU: 0.19,	Loss: 1980.00
# INFO:root:Step 64 of 233,	Accuracy: 0.81,	mIoU: 0.20,	Loss: 1951.02
# INFO:root:Step 69 of 233,	Accuracy: 0.81,	mIoU: 0.21,	Loss: 1946.09
# INFO:root:Step 74 of 233,	Accuracy: 0.81,	mIoU: 0.21,	Loss: 1938.87
# INFO:root:Step 79 of 233,	Accuracy: 0.82,	mIoU: 0.21,	Loss: 1932.94
# INFO:root:Step 84 of 233,	Accuracy: 0.82,	mIoU: 0.21,	Loss: 1935.77
# INFO:root:Step 89 of 233,	Accuracy: 0.81,	mIoU: 0.21,	Loss: 1940.47
# INFO:root:Step 94 of 233,	Accuracy: 0.81,	mIoU: 0.21,	Loss: 1941.24
# INFO:root:Step 99 of 233,	Accuracy: 0.82,	mIoU: 0.21,	Loss: 1951.40
# INFO:root:Step 104 of 233,	Accuracy: 0.82,	mIoU: 0.20,	Loss: 1952.00
# INFO:root:Step 109 of 233,	Accuracy: 0.82,	mIoU: 0.20,	Loss: 1958.60
# INFO:root:Step 114 of 233,	Accuracy: 0.82,	mIoU: 0.20,	Loss: 1935.52
# INFO:root:Step 119 of 233,	Accuracy: 0.82,	mIoU: 0.21,	Loss: 1926.78
# INFO:root:Step 124 of 233,	Accuracy: 0.82,	mIoU: 0.21,	Loss: 1934.14
# INFO:root:Step 129 of 233,	Accuracy: 0.83,	mIoU: 0.22,	Loss: 1925.99
# INFO:root:Step 134 of 233,	Accuracy: 0.83,	mIoU: 0.22,	Loss: 1919.89
# INFO:root:Step 139 of 233,	Accuracy: 0.83,	mIoU: 0.22,	Loss: 1916.63
# INFO:root:Step 144 of 233,	Accuracy: 0.83,	mIoU: 0.22,	Loss: 1928.18
# INFO:root:Step 149 of 233,	Accuracy: 0.83,	mIoU: 0.23,	Loss: 1918.03
# INFO:root:Step 154 of 233,	Accuracy: 0.83,	mIoU: 0.23,	Loss: 1907.36
# INFO:root:Step 159 of 233,	Accuracy: 0.83,	mIoU: 0.23,	Loss: 1899.31
# INFO:root:Step 164 of 233,	Accuracy: 0.83,	mIoU: 0.23,	Loss: 1902.81
# INFO:root:Step 169 of 233,	Accuracy: 0.83,	mIoU: 0.24,	Loss: 1900.81
# INFO:root:Step 174 of 233,	Accuracy: 0.83,	mIoU: 0.24,	Loss: 1897.31
# INFO:root:Step 179 of 233,	Accuracy: 0.84,	mIoU: 0.24,	Loss: 1896.33
# INFO:root:Step 184 of 233,	Accuracy: 0.84,	mIoU: 0.24,	Loss: 1894.68
# INFO:root:Step 189 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1890.55
# INFO:root:Step 194 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1886.07
# INFO:root:Step 199 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1886.72
# INFO:root:Step 204 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1888.32
# INFO:root:Step 209 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1880.15
# INFO:root:Step 214 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1873.78
# INFO:root:Step 219 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1871.83
# INFO:root:Step 224 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1866.55
# INFO:root:Step 229 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1863.51
# INFO:root:Validating
# INFO:root:Training accuracy: 0.84 | Training loss: 1860.90 | Training mIoU: 0.25
# INFO:root:Validation accuracy: 0.92 | Validation loss: 1974.50 | Validation mIoU: 0.27
# INFO:root:Saving with loss of 1974.4990234375, improved over previous 2167.75830078125
# INFO:root:Epoch 4
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.88,	mIoU: 0.15,	Loss: 1863.00
# INFO:root:Step 9 of 233,	Accuracy: 0.87,	mIoU: 0.22,	Loss: 1672.21
# INFO:root:Step 14 of 233,	Accuracy: 0.90,	mIoU: 0.28,	Loss: 1730.64
# INFO:root:Step 19 of 233,	Accuracy: 0.88,	mIoU: 0.26,	Loss: 1759.24
# INFO:root:Step 24 of 233,	Accuracy: 0.88,	mIoU: 0.27,	Loss: 1718.79
# INFO:root:Step 29 of 233,	Accuracy: 0.87,	mIoU: 0.28,	Loss: 1716.21
# INFO:root:Step 34 of 233,	Accuracy: 0.88,	mIoU: 0.25,	Loss: 1723.70
# INFO:root:Step 39 of 233,	Accuracy: 0.88,	mIoU: 0.24,	Loss: 1745.80
# INFO:root:Step 44 of 233,	Accuracy: 0.88,	mIoU: 0.23,	Loss: 1736.60
# INFO:root:Step 49 of 233,	Accuracy: 0.88,	mIoU: 0.23,	Loss: 1738.67
# INFO:root:Step 54 of 233,	Accuracy: 0.86,	mIoU: 0.23,	Loss: 1730.63
# INFO:root:Step 59 of 233,	Accuracy: 0.87,	mIoU: 0.23,	Loss: 1709.76
# INFO:root:Step 64 of 233,	Accuracy: 0.86,	mIoU: 0.23,	Loss: 1717.45
# INFO:root:Step 69 of 233,	Accuracy: 0.86,	mIoU: 0.24,	Loss: 1704.03
# INFO:root:Step 74 of 233,	Accuracy: 0.86,	mIoU: 0.24,	Loss: 1683.76
# INFO:root:Step 79 of 233,	Accuracy: 0.86,	mIoU: 0.24,	Loss: 1674.44
# INFO:root:Step 84 of 233,	Accuracy: 0.87,	mIoU: 0.25,	Loss: 1665.51
# INFO:root:Step 89 of 233,	Accuracy: 0.87,	mIoU: 0.26,	Loss: 1663.49
# INFO:root:Step 94 of 233,	Accuracy: 0.86,	mIoU: 0.26,	Loss: 1671.22
# INFO:root:Step 99 of 233,	Accuracy: 0.86,	mIoU: 0.27,	Loss: 1666.50
# INFO:root:Step 104 of 233,	Accuracy: 0.86,	mIoU: 0.27,	Loss: 1658.91
# INFO:root:Step 109 of 233,	Accuracy: 0.86,	mIoU: 0.28,	Loss: 1661.22
# INFO:root:Step 114 of 233,	Accuracy: 0.87,	mIoU: 0.28,	Loss: 1665.06
# INFO:root:Step 119 of 233,	Accuracy: 0.86,	mIoU: 0.27,	Loss: 1670.44
# INFO:root:Step 124 of 233,	Accuracy: 0.86,	mIoU: 0.28,	Loss: 1669.61
# INFO:root:Step 129 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1664.49
# INFO:root:Step 134 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1658.53
# INFO:root:Step 139 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1658.61
# INFO:root:Step 144 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1656.75
# INFO:root:Step 149 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1656.33
# INFO:root:Step 154 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1659.96
# INFO:root:Step 159 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1657.69
# INFO:root:Step 164 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1660.02
# INFO:root:Step 169 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1667.14
# INFO:root:Step 174 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1661.12
# INFO:root:Step 179 of 233,	Accuracy: 0.86,	mIoU: 0.29,	Loss: 1663.46
# INFO:root:Step 184 of 233,	Accuracy: 0.86,	mIoU: 0.30,	Loss: 1659.24
# INFO:root:Step 189 of 233,	Accuracy: 0.86,	mIoU: 0.30,	Loss: 1656.87
# INFO:root:Step 194 of 233,	Accuracy: 0.86,	mIoU: 0.30,	Loss: 1657.35
# INFO:root:Step 199 of 233,	Accuracy: 0.86,	mIoU: 0.30,	Loss: 1655.10
# INFO:root:Step 204 of 233,	Accuracy: 0.86,	mIoU: 0.30,	Loss: 1645.93
# INFO:root:Step 209 of 233,	Accuracy: 0.86,	mIoU: 0.30,	Loss: 1645.95
# INFO:root:Step 214 of 233,	Accuracy: 0.86,	mIoU: 0.30,	Loss: 1641.94
# INFO:root:Step 219 of 233,	Accuracy: 0.86,	mIoU: 0.30,	Loss: 1635.78
# INFO:root:Step 224 of 233,	Accuracy: 0.87,	mIoU: 0.30,	Loss: 1635.15
# INFO:root:Step 229 of 233,	Accuracy: 0.87,	mIoU: 0.30,	Loss: 1630.08
# INFO:root:Validating
# INFO:root:Training accuracy: 0.87 | Training loss: 1627.62 | Training mIoU: 0.30
# INFO:root:Validation accuracy: 0.93 | Validation loss: 1808.64 | Validation mIoU: 0.23
# INFO:root:Saving with loss of 1808.642333984375, improved over previous 1974.4990234375
# INFO:root:Epoch 5
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.84,	mIoU: 0.32,	Loss: 1556.47
# INFO:root:Step 9 of 233,	Accuracy: 0.84,	mIoU: 0.25,	Loss: 1619.34
# INFO:root:Step 14 of 233,	Accuracy: 0.85,	mIoU: 0.22,	Loss: 1701.65
# INFO:root:Step 19 of 233,	Accuracy: 0.87,	mIoU: 0.27,	Loss: 1629.00
# INFO:root:Step 24 of 233,	Accuracy: 0.86,	mIoU: 0.27,	Loss: 1595.48
# INFO:root:Step 29 of 233,	Accuracy: 0.85,	mIoU: 0.30,	Loss: 1533.19
# INFO:root:Step 34 of 233,	Accuracy: 0.85,	mIoU: 0.31,	Loss: 1556.60
# INFO:root:Step 39 of 233,	Accuracy: 0.85,	mIoU: 0.31,	Loss: 1567.24
# INFO:root:Step 44 of 233,	Accuracy: 0.86,	mIoU: 0.31,	Loss: 1556.54
# INFO:root:Step 49 of 233,	Accuracy: 0.86,	mIoU: 0.31,	Loss: 1559.14
# INFO:root:Step 54 of 233,	Accuracy: 0.86,	mIoU: 0.32,	Loss: 1555.09
# INFO:root:Step 59 of 233,	Accuracy: 0.87,	mIoU: 0.30,	Loss: 1572.75
# INFO:root:Step 64 of 233,	Accuracy: 0.87,	mIoU: 0.31,	Loss: 1563.03
# INFO:root:Step 69 of 233,	Accuracy: 0.87,	mIoU: 0.31,	Loss: 1565.94
# INFO:root:Step 74 of 233,	Accuracy: 0.87,	mIoU: 0.31,	Loss: 1564.48
# INFO:root:Step 79 of 233,	Accuracy: 0.87,	mIoU: 0.30,	Loss: 1556.97
# INFO:root:Step 84 of 233,	Accuracy: 0.88,	mIoU: 0.30,	Loss: 1564.51
# INFO:root:Step 89 of 233,	Accuracy: 0.88,	mIoU: 0.31,	Loss: 1564.00
# INFO:root:Step 94 of 233,	Accuracy: 0.88,	mIoU: 0.31,	Loss: 1561.16
# INFO:root:Step 99 of 233,	Accuracy: 0.87,	mIoU: 0.30,	Loss: 1587.45
# INFO:root:Step 104 of 233,	Accuracy: 0.87,	mIoU: 0.30,	Loss: 1587.05
# INFO:root:Step 109 of 233,	Accuracy: 0.87,	mIoU: 0.31,	Loss: 1578.53
# INFO:root:Step 114 of 233,	Accuracy: 0.87,	mIoU: 0.30,	Loss: 1596.16
# INFO:root:Step 119 of 233,	Accuracy: 0.87,	mIoU: 0.30,	Loss: 1584.68
# INFO:root:Step 124 of 233,	Accuracy: 0.87,	mIoU: 0.31,	Loss: 1591.19
# INFO:root:Step 129 of 233,	Accuracy: 0.87,	mIoU: 0.31,	Loss: 1588.50
# INFO:root:Step 134 of 233,	Accuracy: 0.87,	mIoU: 0.32,	Loss: 1583.02
# INFO:root:Step 139 of 233,	Accuracy: 0.87,	mIoU: 0.31,	Loss: 1578.94
# INFO:root:Step 144 of 233,	Accuracy: 0.87,	mIoU: 0.31,	Loss: 1576.82
# INFO:root:Step 149 of 233,	Accuracy: 0.87,	mIoU: 0.32,	Loss: 1584.14
# INFO:root:Step 154 of 233,	Accuracy: 0.87,	mIoU: 0.32,	Loss: 1587.27
# INFO:root:Step 159 of 233,	Accuracy: 0.87,	mIoU: 0.32,	Loss: 1583.95
# INFO:root:Step 164 of 233,	Accuracy: 0.87,	mIoU: 0.32,	Loss: 1583.81
# INFO:root:Step 169 of 233,	Accuracy: 0.87,	mIoU: 0.32,	Loss: 1575.30
# INFO:root:Step 174 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1573.08
# INFO:root:Step 179 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1578.25
# INFO:root:Step 184 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1574.05
# INFO:root:Step 189 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1574.79
# INFO:root:Step 194 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1574.33
# INFO:root:Step 199 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1579.77
# INFO:root:Step 204 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1571.92
# INFO:root:Step 209 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1576.33
# INFO:root:Step 214 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1576.38
# INFO:root:Step 219 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1574.81
# INFO:root:Step 224 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1575.94
# INFO:root:Step 229 of 233,	Accuracy: 0.87,	mIoU: 0.33,	Loss: 1575.84
# INFO:root:Validating
# INFO:root:Training accuracy: 0.87 | Training loss: 1570.87 | Training mIoU: 0.33
# INFO:root:Validation accuracy: 0.90 | Validation loss: 1791.15 | Validation mIoU: 0.25
# INFO:root:Saving with loss of 1791.1480712890625, improved over previous 1808.642333984375
# INFO:root:Epoch 6
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.93,	mIoU: 0.39,	Loss: 1580.30
# INFO:root:Step 9 of 233,	Accuracy: 0.92,	mIoU: 0.42,	Loss: 1559.38
# INFO:root:Step 14 of 233,	Accuracy: 0.90,	mIoU: 0.41,	Loss: 1533.59
# INFO:root:Step 19 of 233,	Accuracy: 0.89,	mIoU: 0.44,	Loss: 1451.98
# INFO:root:Step 24 of 233,	Accuracy: 0.88,	mIoU: 0.46,	Loss: 1437.02
# INFO:root:Step 29 of 233,	Accuracy: 0.89,	mIoU: 0.44,	Loss: 1444.78
# INFO:root:Step 34 of 233,	Accuracy: 0.89,	mIoU: 0.43,	Loss: 1430.55
# INFO:root:Step 39 of 233,	Accuracy: 0.88,	mIoU: 0.43,	Loss: 1415.59
# INFO:root:Step 44 of 233,	Accuracy: 0.87,	mIoU: 0.41,	Loss: 1434.60
# INFO:root:Step 49 of 233,	Accuracy: 0.87,	mIoU: 0.41,	Loss: 1439.59
# INFO:root:Step 54 of 233,	Accuracy: 0.88,	mIoU: 0.41,	Loss: 1431.73
# INFO:root:Step 59 of 233,	Accuracy: 0.87,	mIoU: 0.42,	Loss: 1424.73
# INFO:root:Step 64 of 233,	Accuracy: 0.87,	mIoU: 0.41,	Loss: 1422.04
# INFO:root:Step 69 of 233,	Accuracy: 0.87,	mIoU: 0.42,	Loss: 1415.12
# INFO:root:Step 74 of 233,	Accuracy: 0.87,	mIoU: 0.42,	Loss: 1409.37
# INFO:root:Step 79 of 233,	Accuracy: 0.87,	mIoU: 0.42,	Loss: 1433.42
# INFO:root:Step 84 of 233,	Accuracy: 0.87,	mIoU: 0.42,	Loss: 1423.83
# INFO:root:Step 89 of 233,	Accuracy: 0.87,	mIoU: 0.42,	Loss: 1422.31
# INFO:root:Step 94 of 233,	Accuracy: 0.87,	mIoU: 0.42,	Loss: 1421.55
# INFO:root:Step 99 of 233,	Accuracy: 0.87,	mIoU: 0.42,	Loss: 1409.85
# INFO:root:Step 104 of 233,	Accuracy: 0.88,	mIoU: 0.42,	Loss: 1414.07
# INFO:root:Step 109 of 233,	Accuracy: 0.88,	mIoU: 0.41,	Loss: 1420.03
# INFO:root:Step 114 of 233,	Accuracy: 0.87,	mIoU: 0.40,	Loss: 1425.18
# INFO:root:Step 119 of 233,	Accuracy: 0.88,	mIoU: 0.40,	Loss: 1432.78
# INFO:root:Step 124 of 233,	Accuracy: 0.88,	mIoU: 0.40,	Loss: 1426.42
# INFO:root:Step 129 of 233,	Accuracy: 0.88,	mIoU: 0.40,	Loss: 1433.45
# INFO:root:Step 134 of 233,	Accuracy: 0.88,	mIoU: 0.39,	Loss: 1442.31
# INFO:root:Step 139 of 233,	Accuracy: 0.88,	mIoU: 0.39,	Loss: 1431.63
# INFO:root:Step 144 of 233,	Accuracy: 0.88,	mIoU: 0.39,	Loss: 1430.69
# INFO:root:Step 149 of 233,	Accuracy: 0.88,	mIoU: 0.40,	Loss: 1434.62
# INFO:root:Step 154 of 233,	Accuracy: 0.88,	mIoU: 0.40,	Loss: 1438.15
# INFO:root:Step 159 of 233,	Accuracy: 0.88,	mIoU: 0.39,	Loss: 1435.71
# INFO:root:Step 164 of 233,	Accuracy: 0.89,	mIoU: 0.40,	Loss: 1430.12
# INFO:root:Step 169 of 233,	Accuracy: 0.89,	mIoU: 0.40,	Loss: 1436.40
# INFO:root:Step 174 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1442.60
# INFO:root:Step 179 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1450.58
# INFO:root:Step 184 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1448.83
# INFO:root:Step 189 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1445.21
# INFO:root:Step 194 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1437.38
# INFO:root:Step 199 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1430.72
# INFO:root:Step 204 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1430.76
# INFO:root:Step 209 of 233,	Accuracy: 0.89,	mIoU: 0.38,	Loss: 1429.50
# INFO:root:Step 214 of 233,	Accuracy: 0.89,	mIoU: 0.38,	Loss: 1440.61
# INFO:root:Step 219 of 233,	Accuracy: 0.89,	mIoU: 0.38,	Loss: 1438.95
# INFO:root:Step 224 of 233,	Accuracy: 0.89,	mIoU: 0.38,	Loss: 1444.78
# INFO:root:Step 229 of 233,	Accuracy: 0.89,	mIoU: 0.38,	Loss: 1454.88
# INFO:root:Validating
# INFO:root:Training accuracy: 0.89 | Training loss: 1456.52 | Training mIoU: 0.38
# INFO:root:Validation accuracy: 0.95 | Validation loss: 1634.81 | Validation mIoU: 0.24
# INFO:root:Saving with loss of 1634.8131103515625, improved over previous 1791.1480712890625
# INFO:root:Epoch 7
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.93,	mIoU: 0.42,	Loss: 1593.14
# INFO:root:Step 9 of 233,	Accuracy: 0.93,	mIoU: 0.46,	Loss: 1534.31
# INFO:root:Step 14 of 233,	Accuracy: 0.93,	mIoU: 0.45,	Loss: 1504.45
# INFO:root:Step 19 of 233,	Accuracy: 0.93,	mIoU: 0.44,	Loss: 1489.87
# INFO:root:Step 24 of 233,	Accuracy: 0.93,	mIoU: 0.43,	Loss: 1487.09
# INFO:root:Step 29 of 233,	Accuracy: 0.92,	mIoU: 0.40,	Loss: 1488.44
# INFO:root:Step 34 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1488.76
# INFO:root:Step 39 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1485.38
# INFO:root:Step 44 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1462.40
# INFO:root:Step 49 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1442.40
# INFO:root:Step 54 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1439.25
# INFO:root:Step 59 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1440.52
# INFO:root:Step 64 of 233,	Accuracy: 0.91,	mIoU: 0.41,	Loss: 1439.13
# INFO:root:Step 69 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1451.71
# INFO:root:Step 74 of 233,	Accuracy: 0.92,	mIoU: 0.40,	Loss: 1454.26
# INFO:root:Step 79 of 233,	Accuracy: 0.92,	mIoU: 0.41,	Loss: 1448.54
# INFO:root:Step 84 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1467.28
# INFO:root:Step 89 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1461.05
# INFO:root:Step 94 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1468.48
# INFO:root:Step 99 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1473.64
# INFO:root:Step 104 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1477.94
# INFO:root:Step 109 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1476.52
# INFO:root:Step 114 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1489.04
# INFO:root:Step 119 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1491.42
# INFO:root:Step 124 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1487.36
# INFO:root:Step 129 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1478.51
# INFO:root:Step 134 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1476.98
# INFO:root:Step 139 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1480.18
# INFO:root:Step 144 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1479.85
# INFO:root:Step 149 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1475.80
# INFO:root:Step 154 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1468.02
# INFO:root:Step 159 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1469.53
# INFO:root:Step 164 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1473.09
# INFO:root:Step 169 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1474.45
# INFO:root:Step 174 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1473.29
# INFO:root:Step 179 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1467.92
# INFO:root:Step 184 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1472.86
# INFO:root:Step 189 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1473.11
# INFO:root:Step 194 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1468.92
# INFO:root:Step 199 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1467.97
# INFO:root:Step 204 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1470.68
# INFO:root:Step 209 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1469.71
# INFO:root:Step 214 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1469.88
# INFO:root:Step 219 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1465.08
# INFO:root:Step 224 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1462.84
# INFO:root:Step 229 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1465.13
# INFO:root:Validating
# INFO:root:Training accuracy: 0.90 | Training loss: 1462.33 | Training mIoU: 0.37
# INFO:root:Validation accuracy: 0.96 | Validation loss: 1595.36 | Validation mIoU: 0.39
# INFO:root:Saving with loss of 1595.3583984375, improved over previous 1634.8131103515625
# INFO:root:Epoch 8
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.94,	mIoU: 0.37,	Loss: 1390.53
# INFO:root:Step 9 of 233,	Accuracy: 0.91,	mIoU: 0.43,	Loss: 1303.90
# INFO:root:Step 14 of 233,	Accuracy: 0.88,	mIoU: 0.41,	Loss: 1366.60
# INFO:root:Step 19 of 233,	Accuracy: 0.88,	mIoU: 0.43,	Loss: 1326.15
# INFO:root:Step 24 of 233,	Accuracy: 0.89,	mIoU: 0.41,	Loss: 1344.47
# INFO:root:Step 29 of 233,	Accuracy: 0.88,	mIoU: 0.40,	Loss: 1409.84
# INFO:root:Step 34 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1397.70
# INFO:root:Step 39 of 233,	Accuracy: 0.89,	mIoU: 0.39,	Loss: 1380.07
# INFO:root:Step 44 of 233,	Accuracy: 0.89,	mIoU: 0.37,	Loss: 1389.65
# INFO:root:Step 49 of 233,	Accuracy: 0.90,	mIoU: 0.38,	Loss: 1392.70
# INFO:root:Step 54 of 233,	Accuracy: 0.90,	mIoU: 0.37,	Loss: 1397.64
# INFO:root:Step 59 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 1400.64
# INFO:root:Step 64 of 233,	Accuracy: 0.90,	mIoU: 0.37,	Loss: 1399.81
# INFO:root:Step 69 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 1388.56
# INFO:root:Step 74 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 1388.38
# INFO:root:Step 79 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1379.26
# INFO:root:Step 84 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1377.80
# INFO:root:Step 89 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 1381.64
# INFO:root:Step 94 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1390.34
# INFO:root:Step 99 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1391.06
# INFO:root:Step 104 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1398.76
# INFO:root:Step 109 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1384.07
# INFO:root:Step 114 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1379.65
# INFO:root:Step 119 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1376.96
# INFO:root:Step 124 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1385.02
# INFO:root:Step 129 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1383.12
# INFO:root:Step 134 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1381.62
# INFO:root:Step 139 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1383.57
# INFO:root:Step 144 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1390.14
# INFO:root:Step 149 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1387.75
# INFO:root:Step 154 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1390.45
# INFO:root:Step 159 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1384.20
# INFO:root:Step 164 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 1381.18
# INFO:root:Step 169 of 233,	Accuracy: 0.91,	mIoU: 0.36,	Loss: 1386.45
# INFO:root:Step 174 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1390.28
# INFO:root:Step 179 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1388.70
# INFO:root:Step 184 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1380.75
# INFO:root:Step 189 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1379.22
# INFO:root:Step 194 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1387.88
# INFO:root:Step 199 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1388.18
# INFO:root:Step 204 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1389.77
# INFO:root:Step 209 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1400.71
# INFO:root:Step 214 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1402.90
# INFO:root:Step 219 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1403.10
# INFO:root:Step 224 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1402.59
# INFO:root:Step 229 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1399.35
# INFO:root:Validating
# INFO:root:Training accuracy: 0.92 | Training loss: 1399.03 | Training mIoU: 0.37
# INFO:root:Validation accuracy: 0.95 | Validation loss: 1503.46 | Validation mIoU: 0.36
# INFO:root:Saving with loss of 1503.456787109375, improved over previous 1595.3583984375
# INFO:root:Epoch 9
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.95,	mIoU: 0.55,	Loss: 1018.78
# INFO:root:Step 9 of 233,	Accuracy: 0.93,	mIoU: 0.42,	Loss: 1184.03
# INFO:root:Step 14 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1196.13
# INFO:root:Step 19 of 233,	Accuracy: 0.93,	mIoU: 0.39,	Loss: 1189.52
# INFO:root:Step 24 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1220.25
# INFO:root:Step 29 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1227.78
# INFO:root:Step 34 of 233,	Accuracy: 0.92,	mIoU: 0.36,	Loss: 1228.11
# INFO:root:Step 39 of 233,	Accuracy: 0.92,	mIoU: 0.36,	Loss: 1244.39
# INFO:root:Step 44 of 233,	Accuracy: 0.92,	mIoU: 0.36,	Loss: 1256.88
# INFO:root:Step 49 of 233,	Accuracy: 0.93,	mIoU: 0.37,	Loss: 1271.07
# INFO:root:Step 54 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1274.87
# INFO:root:Step 59 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1271.24
# INFO:root:Step 64 of 233,	Accuracy: 0.92,	mIoU: 0.37,	Loss: 1281.79
# INFO:root:Step 69 of 233,	Accuracy: 0.92,	mIoU: 0.38,	Loss: 1262.72
# INFO:root:Step 74 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1256.12
# INFO:root:Step 79 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1268.80
# INFO:root:Step 84 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1256.80
# INFO:root:Step 89 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1241.10
# INFO:root:Step 94 of 233,	Accuracy: 0.92,	mIoU: 0.40,	Loss: 1234.54
# INFO:root:Step 99 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1225.40
# INFO:root:Step 104 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1231.06
# INFO:root:Step 109 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1240.83
# INFO:root:Step 114 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1240.20
# INFO:root:Step 119 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1229.97
# INFO:root:Step 124 of 233,	Accuracy: 0.92,	mIoU: 0.39,	Loss: 1230.73
# INFO:root:Step 129 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1224.59
# INFO:root:Step 134 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1221.72
# INFO:root:Step 139 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1221.55
# INFO:root:Step 144 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1218.98
# INFO:root:Step 149 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1208.80
# INFO:root:Step 154 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1208.53
# INFO:root:Step 159 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1202.96
# INFO:root:Step 164 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1196.59
# INFO:root:Step 169 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 1191.48
# INFO:root:Step 174 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1190.13
# INFO:root:Step 179 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1191.81
# INFO:root:Step 184 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1184.57
# INFO:root:Step 189 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1178.08
# INFO:root:Step 194 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1174.91
# INFO:root:Step 199 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1173.07
# INFO:root:Step 204 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1168.52
# INFO:root:Step 209 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1166.37
# INFO:root:Step 214 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1169.98
# INFO:root:Step 219 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1162.28
# INFO:root:Step 224 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 1158.98
# INFO:root:Step 229 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 1156.86
# INFO:root:Validating
# INFO:root:Training accuracy: 0.90 | Training loss: 1154.34 | Training mIoU: 0.39
# INFO:root:Validation accuracy: 0.95 | Validation loss: 1094.23 | Validation mIoU: 0.34
# INFO:root:Saving with loss of 1094.2335205078125, improved over previous 1503.456787109375
# INFO:root:Epoch 10
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.86,	mIoU: 0.36,	Loss: 963.14
# INFO:root:Step 9 of 233,	Accuracy: 0.88,	mIoU: 0.38,	Loss: 1050.28
# INFO:root:Step 14 of 233,	Accuracy: 0.89,	mIoU: 0.47,	Loss: 981.96
# INFO:root:Step 19 of 233,	Accuracy: 0.87,	mIoU: 0.44,	Loss: 967.97
# INFO:root:Step 24 of 233,	Accuracy: 0.84,	mIoU: 0.48,	Loss: 929.07
# INFO:root:Step 29 of 233,	Accuracy: 0.86,	mIoU: 0.49,	Loss: 942.34
# INFO:root:Step 34 of 233,	Accuracy: 0.87,	mIoU: 0.50,	Loss: 949.88
# INFO:root:Step 39 of 233,	Accuracy: 0.87,	mIoU: 0.49,	Loss: 931.90
# INFO:root:Step 44 of 233,	Accuracy: 0.88,	mIoU: 0.46,	Loss: 936.75
# INFO:root:Step 49 of 233,	Accuracy: 0.89,	mIoU: 0.46,	Loss: 935.74
# INFO:root:Step 54 of 233,	Accuracy: 0.89,	mIoU: 0.45,	Loss: 942.67
# INFO:root:Step 59 of 233,	Accuracy: 0.89,	mIoU: 0.45,	Loss: 942.89
# INFO:root:Step 64 of 233,	Accuracy: 0.89,	mIoU: 0.45,	Loss: 934.72
# INFO:root:Step 69 of 233,	Accuracy: 0.89,	mIoU: 0.45,	Loss: 919.74
# INFO:root:Step 74 of 233,	Accuracy: 0.90,	mIoU: 0.45,	Loss: 918.36
# INFO:root:Step 79 of 233,	Accuracy: 0.90,	mIoU: 0.44,	Loss: 918.88
# INFO:root:Step 84 of 233,	Accuracy: 0.90,	mIoU: 0.45,	Loss: 925.56
# INFO:root:Step 89 of 233,	Accuracy: 0.90,	mIoU: 0.45,	Loss: 927.93
# INFO:root:Step 94 of 233,	Accuracy: 0.90,	mIoU: 0.46,	Loss: 922.18
# INFO:root:Step 99 of 233,	Accuracy: 0.90,	mIoU: 0.46,	Loss: 919.43
# INFO:root:Step 104 of 233,	Accuracy: 0.90,	mIoU: 0.44,	Loss: 923.04
# INFO:root:Step 109 of 233,	Accuracy: 0.90,	mIoU: 0.44,	Loss: 923.20
# INFO:root:Step 114 of 233,	Accuracy: 0.90,	mIoU: 0.44,	Loss: 930.60
# INFO:root:Step 119 of 233,	Accuracy: 0.90,	mIoU: 0.45,	Loss: 926.77
# INFO:root:Step 124 of 233,	Accuracy: 0.89,	mIoU: 0.45,	Loss: 926.10
# INFO:root:Step 129 of 233,	Accuracy: 0.90,	mIoU: 0.44,	Loss: 921.77
# INFO:root:Step 134 of 233,	Accuracy: 0.90,	mIoU: 0.43,	Loss: 924.49
# INFO:root:Step 139 of 233,	Accuracy: 0.90,	mIoU: 0.43,	Loss: 925.30
# INFO:root:Step 144 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 928.79
# INFO:root:Step 149 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 926.93
# INFO:root:Step 154 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 924.61
# INFO:root:Step 159 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 918.75
# INFO:root:Step 164 of 233,	Accuracy: 0.90,	mIoU: 0.43,	Loss: 917.18
# INFO:root:Step 169 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 916.77
# INFO:root:Step 174 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 915.33
# INFO:root:Step 179 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 913.15
# INFO:root:Step 184 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 914.26
# INFO:root:Step 189 of 233,	Accuracy: 0.90,	mIoU: 0.42,	Loss: 914.46
# INFO:root:Step 194 of 233,	Accuracy: 0.90,	mIoU: 0.41,	Loss: 921.08
# INFO:root:Step 199 of 233,	Accuracy: 0.90,	mIoU: 0.41,	Loss: 923.70
# INFO:root:Step 204 of 233,	Accuracy: 0.89,	mIoU: 0.41,	Loss: 919.74
# INFO:root:Step 209 of 233,	Accuracy: 0.89,	mIoU: 0.40,	Loss: 920.50
# INFO:root:Step 214 of 233,	Accuracy: 0.89,	mIoU: 0.40,	Loss: 922.46
# INFO:root:Step 219 of 233,	Accuracy: 0.89,	mIoU: 0.41,	Loss: 919.69
# INFO:root:Step 224 of 233,	Accuracy: 0.90,	mIoU: 0.40,	Loss: 919.35
# INFO:root:Step 229 of 233,	Accuracy: 0.90,	mIoU: 0.40,	Loss: 917.57
# INFO:root:Validating
# INFO:root:Training accuracy: 0.90 | Training loss: 919.64 | Training mIoU: 0.40
# INFO:root:Validation accuracy: 0.91 | Validation loss: 974.25 | Validation mIoU: 0.40
# INFO:root:Saving with loss of 974.2525634765625, improved over previous 1094.2335205078125
# INFO:root:Epoch 11
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.93,	mIoU: 0.23,	Loss: 847.71
# INFO:root:Step 9 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 824.64
# INFO:root:Step 14 of 233,	Accuracy: 0.90,	mIoU: 0.41,	Loss: 804.12
# INFO:root:Step 19 of 233,	Accuracy: 0.91,	mIoU: 0.41,	Loss: 859.18
# INFO:root:Step 24 of 233,	Accuracy: 0.91,	mIoU: 0.41,	Loss: 868.87
# INFO:root:Step 29 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 863.45
# INFO:root:Step 34 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 879.46
# INFO:root:Step 39 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 882.80
# INFO:root:Step 44 of 233,	Accuracy: 0.91,	mIoU: 0.36,	Loss: 896.28
# INFO:root:Step 49 of 233,	Accuracy: 0.91,	mIoU: 0.36,	Loss: 910.48
# INFO:root:Step 54 of 233,	Accuracy: 0.91,	mIoU: 0.36,	Loss: 906.16
# INFO:root:Step 59 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 914.26
# INFO:root:Step 64 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 904.85
# INFO:root:Step 69 of 233,	Accuracy: 0.91,	mIoU: 0.35,	Loss: 895.03
# INFO:root:Step 74 of 233,	Accuracy: 0.91,	mIoU: 0.36,	Loss: 890.05
# INFO:root:Step 79 of 233,	Accuracy: 0.91,	mIoU: 0.37,	Loss: 872.15
# INFO:root:Step 84 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 876.22
# INFO:root:Step 89 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 876.61
# INFO:root:Step 94 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 873.94
# INFO:root:Step 99 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 872.58
# INFO:root:Step 104 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 870.32
# INFO:root:Step 109 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 875.31
# INFO:root:Step 114 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 871.96
# INFO:root:Step 119 of 233,	Accuracy: 0.91,	mIoU: 0.38,	Loss: 871.32
# INFO:root:Step 124 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 867.85
# INFO:root:Step 129 of 233,	Accuracy: 0.90,	mIoU: 0.39,	Loss: 863.70
# INFO:root:Step 134 of 233,	Accuracy: 0.91,	mIoU: 0.39,	Loss: 855.96
# INFO:root:Step 139 of 233,	Accuracy: 0.90,	mIoU: 0.39,	Loss: 850.71
# INFO:root:Step 144 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 852.23
# INFO:root:Step 149 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 849.15
# INFO:root:Step 154 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 844.20
# INFO:root:Step 159 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 844.23
# INFO:root:Step 164 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 848.38
# INFO:root:Step 169 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 843.66
# INFO:root:Step 174 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 840.75
# INFO:root:Step 179 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 842.75
# INFO:root:Step 184 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 849.22
# INFO:root:Step 189 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 847.56
# INFO:root:Step 194 of 233,	Accuracy: 0.91,	mIoU: 0.41,	Loss: 852.57
# INFO:root:Step 199 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 853.08
# INFO:root:Step 204 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 859.71
# INFO:root:Step 209 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 860.30
# INFO:root:Step 214 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 861.10
# INFO:root:Step 219 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 860.47
# INFO:root:Step 224 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 859.46
# INFO:root:Step 229 of 233,	Accuracy: 0.91,	mIoU: 0.40,	Loss: 863.65
# INFO:root:Validating
# INFO:root:Training accuracy: 0.91 | Training loss: 863.17 | Training mIoU: 0.40
# INFO:root:Validation accuracy: 0.95 | Validation loss: 861.40 | Validation mIoU: 0.42
# INFO:root:Saving with loss of 861.4025268554688, improved over previous 974.2525634765625
# INFO:root:Epoch 12
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.95,	mIoU: 0.55,	Loss: 589.32
# INFO:root:Step 9 of 233,	Accuracy: 0.97,	mIoU: 0.48,	Loss: 780.49
# INFO:root:Step 14 of 233,	Accuracy: 0.94,	mIoU: 0.38,	Loss: 846.34
# INFO:root:Step 19 of 233,	Accuracy: 0.92,	mIoU: 0.44,	Loss: 838.66
# INFO:root:Step 24 of 233,	Accuracy: 0.93,	mIoU: 0.44,	Loss: 828.03
# INFO:root:Step 29 of 233,	Accuracy: 0.93,	mIoU: 0.46,	Loss: 801.41
# INFO:root:Step 34 of 233,	Accuracy: 0.92,	mIoU: 0.48,	Loss: 811.70
# INFO:root:Step 39 of 233,	Accuracy: 0.92,	mIoU: 0.48,	Loss: 816.05
# INFO:root:Step 44 of 233,	Accuracy: 0.92,	mIoU: 0.44,	Loss: 835.29
# INFO:root:Step 49 of 233,	Accuracy: 0.93,	mIoU: 0.44,	Loss: 863.40
# INFO:root:Step 54 of 233,	Accuracy: 0.92,	mIoU: 0.44,	Loss: 849.75
# INFO:root:Step 59 of 233,	Accuracy: 0.92,	mIoU: 0.45,	Loss: 840.66
# INFO:root:Step 64 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 826.96
# INFO:root:Step 69 of 233,	Accuracy: 0.92,	mIoU: 0.45,	Loss: 823.58
# INFO:root:Step 74 of 233,	Accuracy: 0.92,	mIoU: 0.45,	Loss: 816.69
# INFO:root:Step 79 of 233,	Accuracy: 0.92,	mIoU: 0.45,	Loss: 815.57
# INFO:root:Step 84 of 233,	Accuracy: 0.91,	mIoU: 0.45,	Loss: 814.96
# INFO:root:Step 89 of 233,	Accuracy: 0.91,	mIoU: 0.44,	Loss: 812.63
# INFO:root:Step 94 of 233,	Accuracy: 0.91,	mIoU: 0.44,	Loss: 817.11
# INFO:root:Step 99 of 233,	Accuracy: 0.91,	mIoU: 0.44,	Loss: 812.58
# INFO:root:Step 104 of 233,	Accuracy: 0.91,	mIoU: 0.45,	Loss: 807.48
# INFO:root:Step 109 of 233,	Accuracy: 0.91,	mIoU: 0.45,	Loss: 796.67
# INFO:root:Step 114 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 787.81
# INFO:root:Step 119 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 791.02
# INFO:root:Step 124 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 784.79
# INFO:root:Step 129 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 777.73
# INFO:root:Step 134 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 777.35
# INFO:root:Step 139 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 776.05
# INFO:root:Step 144 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 774.06
# INFO:root:Step 149 of 233,	Accuracy: 0.90,	mIoU: 0.46,	Loss: 772.42
# INFO:root:Step 154 of 233,	Accuracy: 0.90,	mIoU: 0.46,	Loss: 771.25
# INFO:root:Step 159 of 233,	Accuracy: 0.90,	mIoU: 0.46,	Loss: 774.00
# INFO:root:Step 164 of 233,	Accuracy: 0.90,	mIoU: 0.46,	Loss: 771.85
# INFO:root:Step 169 of 233,	Accuracy: 0.90,	mIoU: 0.46,	Loss: 774.94
# INFO:root:Step 174 of 233,	Accuracy: 0.90,	mIoU: 0.46,	Loss: 772.46
# INFO:root:Step 179 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 771.90
# INFO:root:Step 184 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 772.97
# INFO:root:Step 189 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 772.06
# INFO:root:Step 194 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 770.76
# INFO:root:Step 199 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 770.61
# INFO:root:Step 204 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 769.44
# INFO:root:Step 209 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 768.13
# INFO:root:Step 214 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 766.51
# INFO:root:Step 219 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 770.78
# INFO:root:Step 224 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 771.35
# INFO:root:Step 229 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 773.22
# INFO:root:Validating
# INFO:root:Training accuracy: 0.91 | Training loss: 773.82 | Training mIoU: 0.46
# INFO:root:Validation accuracy: 0.92 | Validation loss: 797.24 | Validation mIoU: 0.49
# INFO:root:Saving with loss of 797.2413330078125, improved over previous 861.4025268554688
# INFO:root:Epoch 13
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.89,	mIoU: 0.59,	Loss: 822.27
# INFO:root:Step 9 of 233,	Accuracy: 0.89,	mIoU: 0.56,	Loss: 706.69
# INFO:root:Step 14 of 233,	Accuracy: 0.88,	mIoU: 0.53,	Loss: 712.22
# INFO:root:Step 19 of 233,	Accuracy: 0.87,	mIoU: 0.50,	Loss: 726.46
# INFO:root:Step 24 of 233,	Accuracy: 0.87,	mIoU: 0.50,	Loss: 761.17
# INFO:root:Step 29 of 233,	Accuracy: 0.89,	mIoU: 0.48,	Loss: 789.60
# INFO:root:Step 34 of 233,	Accuracy: 0.90,	mIoU: 0.49,	Loss: 765.43
# INFO:root:Step 39 of 233,	Accuracy: 0.90,	mIoU: 0.49,	Loss: 773.55
# INFO:root:Step 44 of 233,	Accuracy: 0.90,	mIoU: 0.50,	Loss: 778.91
# INFO:root:Step 49 of 233,	Accuracy: 0.90,	mIoU: 0.50,	Loss: 774.51
# INFO:root:Step 54 of 233,	Accuracy: 0.91,	mIoU: 0.49,	Loss: 768.82
# INFO:root:Step 59 of 233,	Accuracy: 0.91,	mIoU: 0.49,	Loss: 759.83
# INFO:root:Step 64 of 233,	Accuracy: 0.91,	mIoU: 0.48,	Loss: 749.57
# INFO:root:Step 69 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 762.29
# INFO:root:Step 74 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 763.96
# INFO:root:Step 79 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 760.40
# INFO:root:Step 84 of 233,	Accuracy: 0.90,	mIoU: 0.47,	Loss: 762.37
# INFO:root:Step 89 of 233,	Accuracy: 0.91,	mIoU: 0.48,	Loss: 752.08
# INFO:root:Step 94 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 759.63
# INFO:root:Step 99 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 754.89
# INFO:root:Step 104 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 754.80
# INFO:root:Step 109 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 761.88
# INFO:root:Step 114 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 768.58
# INFO:root:Step 119 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 774.86
# INFO:root:Step 124 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 775.88
# INFO:root:Step 129 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 769.86
# INFO:root:Step 134 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 770.59
# INFO:root:Step 139 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 765.10
# INFO:root:Step 144 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 762.40
# INFO:root:Step 149 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 764.40
# INFO:root:Step 154 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 761.88
# INFO:root:Step 159 of 233,	Accuracy: 0.91,	mIoU: 0.46,	Loss: 760.18
# INFO:root:Step 164 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 756.99
# INFO:root:Step 169 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 757.71
# INFO:root:Step 174 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 757.63
# INFO:root:Step 179 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 758.20
# INFO:root:Step 184 of 233,	Accuracy: 0.91,	mIoU: 0.47,	Loss: 757.51
# INFO:root:Step 189 of 233,	Accuracy: 0.90,	mIoU: 0.47,	Loss: 757.26
# INFO:root:Step 194 of 233,	Accuracy: 0.91,	mIoU: 0.48,	Loss: 757.47
# INFO:root:Step 199 of 233,	Accuracy: 0.90,	mIoU: 0.48,	Loss: 754.66
# INFO:root:Step 204 of 233,	Accuracy: 0.90,	mIoU: 0.48,	Loss: 751.95
# INFO:root:Step 209 of 233,	Accuracy: 0.90,	mIoU: 0.48,	Loss: 751.52
# INFO:root:Step 214 of 233,	Accuracy: 0.90,	mIoU: 0.49,	Loss: 750.75
# INFO:root:Step 219 of 233,	Accuracy: 0.90,	mIoU: 0.49,	Loss: 751.66
# INFO:root:Step 224 of 233,	Accuracy: 0.90,	mIoU: 0.49,	Loss: 746.55
# INFO:root:Step 229 of 233,	Accuracy: 0.90,	mIoU: 0.48,	Loss: 744.59
# INFO:root:Validating
# INFO:root:Training accuracy: 0.90 | Training loss: 744.79 | Training mIoU: 0.49
# INFO:root:Validation accuracy: 0.91 | Validation loss: 748.38 | Validation mIoU: 0.57
# INFO:root:Saving with loss of 748.3822021484375, improved over previous 797.2413330078125
# INFO:root:Epoch 14
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.90,	mIoU: 0.55,	Loss: 706.52
# INFO:root:Step 9 of 233,	Accuracy: 0.89,	mIoU: 0.51,	Loss: 658.19
# INFO:root:Step 14 of 233,	Accuracy: 0.91,	mIoU: 0.52,	Loss: 657.84
# INFO:root:Step 19 of 233,	Accuracy: 0.89,	mIoU: 0.49,	Loss: 653.74
# INFO:root:Step 24 of 233,	Accuracy: 0.90,	mIoU: 0.51,	Loss: 630.58
# INFO:root:Step 29 of 233,	Accuracy: 0.89,	mIoU: 0.52,	Loss: 631.79
# INFO:root:Step 34 of 233,	Accuracy: 0.89,	mIoU: 0.54,	Loss: 631.96
# INFO:root:Step 39 of 233,	Accuracy: 0.89,	mIoU: 0.53,	Loss: 635.19
# INFO:root:Step 44 of 233,	Accuracy: 0.89,	mIoU: 0.52,	Loss: 636.03
# INFO:root:Step 49 of 233,	Accuracy: 0.90,	mIoU: 0.51,	Loss: 677.54
# INFO:root:Step 54 of 233,	Accuracy: 0.89,	mIoU: 0.49,	Loss: 681.92
# INFO:root:Step 59 of 233,	Accuracy: 0.89,	mIoU: 0.49,	Loss: 680.36
# INFO:root:Step 64 of 233,	Accuracy: 0.89,	mIoU: 0.48,	Loss: 680.14
# INFO:root:Step 69 of 233,	Accuracy: 0.88,	mIoU: 0.49,	Loss: 676.06
# INFO:root:Step 74 of 233,	Accuracy: 0.88,	mIoU: 0.50,	Loss: 675.15
# INFO:root:Step 79 of 233,	Accuracy: 0.88,	mIoU: 0.51,	Loss: 675.41
# INFO:root:Step 84 of 233,	Accuracy: 0.88,	mIoU: 0.51,	Loss: 668.11
# INFO:root:Step 89 of 233,	Accuracy: 0.88,	mIoU: 0.51,	Loss: 667.56
# INFO:root:Step 94 of 233,	Accuracy: 0.88,	mIoU: 0.52,	Loss: 660.71
# INFO:root:Step 99 of 233,	Accuracy: 0.88,	mIoU: 0.52,	Loss: 658.33
# INFO:root:Step 104 of 233,	Accuracy: 0.88,	mIoU: 0.52,	Loss: 660.35
# INFO:root:Step 109 of 233,	Accuracy: 0.88,	mIoU: 0.52,	Loss: 656.06
# INFO:root:Step 114 of 233,	Accuracy: 0.88,	mIoU: 0.52,	Loss: 654.14
# INFO:root:Step 119 of 233,	Accuracy: 0.88,	mIoU: 0.53,	Loss: 650.51
# INFO:root:Step 124 of 233,	Accuracy: 0.88,	mIoU: 0.53,	Loss: 644.31
# INFO:root:Step 129 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 644.41
# INFO:root:Step 134 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 642.80
# INFO:root:Step 139 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 638.62
# INFO:root:Step 144 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 634.24
# INFO:root:Step 149 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 634.99
# INFO:root:Step 154 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 631.49
# INFO:root:Step 159 of 233,	Accuracy: 0.87,	mIoU: 0.54,	Loss: 628.96
# INFO:root:Step 164 of 233,	Accuracy: 0.87,	mIoU: 0.54,	Loss: 629.21
# INFO:root:Step 169 of 233,	Accuracy: 0.87,	mIoU: 0.54,	Loss: 628.88
# INFO:root:Step 174 of 233,	Accuracy: 0.87,	mIoU: 0.54,	Loss: 629.38
# INFO:root:Step 179 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 627.29
# INFO:root:Step 184 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 624.76
# INFO:root:Step 189 of 233,	Accuracy: 0.87,	mIoU: 0.53,	Loss: 625.19
# INFO:root:Step 194 of 233,	Accuracy: 0.86,	mIoU: 0.54,	Loss: 622.54
# INFO:root:Step 199 of 233,	Accuracy: 0.86,	mIoU: 0.54,	Loss: 621.33
# INFO:root:Step 204 of 233,	Accuracy: 0.86,	mIoU: 0.54,	Loss: 615.42
# INFO:root:Step 209 of 233,	Accuracy: 0.86,	mIoU: 0.54,	Loss: 613.97
# INFO:root:Step 214 of 233,	Accuracy: 0.86,	mIoU: 0.54,	Loss: 609.37
# INFO:root:Step 219 of 233,	Accuracy: 0.86,	mIoU: 0.54,	Loss: 605.89
# INFO:root:Step 224 of 233,	Accuracy: 0.86,	mIoU: 0.55,	Loss: 606.07
# ...
# INFO:root:Step 54 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 46.71
# INFO:root:Step 59 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 45.88
# INFO:root:Step 64 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 45.17
# INFO:root:Step 69 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 45.19
# INFO:root:Step 74 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 45.37
# INFO:root:Step 79 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 45.21
# INFO:root:Step 84 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 44.98
# INFO:root:Step 89 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 45.05
# INFO:root:Step 94 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 44.97
# INFO:root:Step 99 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 45.10
# INFO:root:Step 104 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 45.35
# INFO:root:Step 109 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 44.86
# INFO:root:Step 114 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 45.22
# INFO:root:Step 119 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 45.21
# INFO:root:Step 124 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 45.09
# INFO:root:Step 129 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 45.35
# INFO:root:Step 134 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 45.83
# INFO:root:Step 139 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 45.91
# INFO:root:Step 144 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 46.10
# INFO:root:Step 149 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 46.22
# INFO:root:Step 154 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 46.07
# INFO:root:Step 159 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 46.38
# INFO:root:Step 164 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 46.27
# INFO:root:Step 169 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 46.30
# INFO:root:Step 174 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 46.42
# INFO:root:Step 179 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.55
# INFO:root:Step 184 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.46
# INFO:root:Step 189 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.38
# INFO:root:Step 194 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.27
# INFO:root:Step 199 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.18
# INFO:root:Step 204 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.06
# INFO:root:Step 209 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 45.97
# INFO:root:Step 214 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 45.96
# INFO:root:Step 219 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.13
# INFO:root:Step 224 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.06
# INFO:root:Step 229 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 46.04
# INFO:root:Validating
# INFO:root:Training accuracy: 1.00 | Training loss: 48.30 | Training mIoU: 0.82
# INFO:root:Validation accuracy: 0.99 | Validation loss: 94.16 | Validation mIoU: 0.76
# INFO:root:Epoch 97
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 1.00,	mIoU: 0.77,	Loss: 46.78
# INFO:root:Step 9 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.92
# INFO:root:Step 14 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 51.83
# INFO:root:Step 19 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 51.38
# INFO:root:Step 24 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 51.57
# INFO:root:Step 29 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 49.09
# INFO:root:Step 34 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 50.65
# INFO:root:Step 39 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 51.51
# INFO:root:Step 44 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 50.38
# INFO:root:Step 49 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.95
# INFO:root:Step 54 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 50.61
# INFO:root:Step 59 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 50.80
# INFO:root:Step 64 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 50.05
# INFO:root:Step 69 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.81
# INFO:root:Step 74 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.21
# INFO:root:Step 79 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.90
# INFO:root:Step 84 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.49
# INFO:root:Step 89 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.89
# INFO:root:Step 94 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.31
# INFO:root:Step 99 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.01
# INFO:root:Step 104 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.19
# INFO:root:Step 109 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.93
# INFO:root:Step 114 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.44
# INFO:root:Step 119 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.46
# INFO:root:Step 124 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.45
# INFO:root:Step 129 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.50
# INFO:root:Step 134 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.31
# INFO:root:Step 139 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.64
# INFO:root:Step 144 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.07
# INFO:root:Step 149 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.74
# INFO:root:Step 154 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.95
# INFO:root:Step 159 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.59
# INFO:root:Step 164 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.59
# INFO:root:Step 169 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.65
# INFO:root:Step 174 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.77
# INFO:root:Step 179 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.75
# INFO:root:Step 184 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.75
# INFO:root:Step 189 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 48.12
# INFO:root:Step 194 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 48.09
# INFO:root:Step 199 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.04
# INFO:root:Step 204 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 48.08
# INFO:root:Step 209 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.96
# INFO:root:Step 214 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.80
# INFO:root:Step 219 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.70
# INFO:root:Step 224 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.83
# INFO:root:Step 229 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.58
# INFO:root:Validating
# INFO:root:Training accuracy: 1.00 | Training loss: 47.70 | Training mIoU: 0.83
# INFO:root:Validation accuracy: 0.99 | Validation loss: 84.29 | Validation mIoU: 0.84
# INFO:root:Saving with loss of 84.2942123413086, improved over previous 86.89065551757812
# INFO:root:Epoch 98
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 1.00,	mIoU: 0.88,	Loss: 45.94
# INFO:root:Step 9 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 46.23
# INFO:root:Step 14 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 43.70
# INFO:root:Step 19 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 44.21
# INFO:root:Step 24 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 50.46
# INFO:root:Step 29 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 46.87
# INFO:root:Step 34 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.22
# INFO:root:Step 39 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 45.76
# INFO:root:Step 44 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 45.28
# INFO:root:Step 49 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.50
# INFO:root:Step 54 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.68
# INFO:root:Step 59 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 45.57
# INFO:root:Step 64 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.97
# INFO:root:Step 69 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.87
# INFO:root:Step 74 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.69
# INFO:root:Step 79 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.26
# INFO:root:Step 84 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.02
# INFO:root:Step 89 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.27
# INFO:root:Step 94 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.28
# INFO:root:Step 99 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.16
# INFO:root:Step 104 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.94
# INFO:root:Step 109 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.94
# INFO:root:Step 114 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.83
# INFO:root:Step 119 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.46
# INFO:root:Step 124 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.46
# INFO:root:Step 129 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.29
# INFO:root:Step 134 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.12
# INFO:root:Step 139 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.80
# INFO:root:Step 144 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.63
# INFO:root:Step 149 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.70
# INFO:root:Step 154 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.72
# INFO:root:Step 159 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.88
# INFO:root:Step 164 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.30
# INFO:root:Step 169 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.22
# INFO:root:Step 174 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 47.28
# INFO:root:Step 179 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 47.29
# INFO:root:Step 184 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 47.34
# INFO:root:Step 189 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 47.31
# INFO:root:Step 194 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 47.05
# INFO:root:Step 199 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 46.94
# INFO:root:Step 204 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 47.02
# INFO:root:Step 209 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 46.89
# INFO:root:Step 214 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 46.77
# INFO:root:Step 219 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 46.61
# INFO:root:Step 224 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 46.54
# INFO:root:Step 229 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 46.49
# INFO:root:Validating
# INFO:root:Training accuracy: 1.00 | Training loss: 46.47 | Training mIoU: 0.84
# INFO:root:Validation accuracy: 0.99 | Validation loss: 84.20 | Validation mIoU: 0.82
# INFO:root:Saving with loss of 84.20149230957031, improved over previous 84.2942123413086
# INFO:root:Epoch 99
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 1.00,	mIoU: 0.88,	Loss: 55.09
# INFO:root:Step 9 of 233,	Accuracy: 1.00,	mIoU: 0.81,	Loss: 57.85
# INFO:root:Step 14 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 56.64
# INFO:root:Step 19 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 54.98
# INFO:root:Step 24 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 55.73
# INFO:root:Step 29 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 52.64
# INFO:root:Step 34 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 53.16
# INFO:root:Step 39 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 52.62
# INFO:root:Step 44 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 52.12
# INFO:root:Step 49 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 51.94
# INFO:root:Step 54 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 50.72
# INFO:root:Step 59 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 50.14
# INFO:root:Step 64 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 50.52
# INFO:root:Step 69 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 49.67
# INFO:root:Step 74 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 49.50
# INFO:root:Step 79 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 49.36
# INFO:root:Step 84 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 49.48
# INFO:root:Step 89 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 48.99
# INFO:root:Step 94 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 49.31
# INFO:root:Step 99 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 48.49
# INFO:root:Step 104 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 48.46
# INFO:root:Step 109 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 48.36
# INFO:root:Step 114 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 48.48
# INFO:root:Step 119 of 233,	Accuracy: 1.00,	mIoU: 0.82,	Loss: 48.20
# INFO:root:Step 124 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.89
# INFO:root:Step 129 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.52
# INFO:root:Step 134 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.54
# INFO:root:Step 139 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.42
# INFO:root:Step 144 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.59
# INFO:root:Step 149 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.46
# INFO:root:Step 154 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.39
# INFO:root:Step 159 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.22
# INFO:root:Step 164 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.05
# INFO:root:Step 169 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.19
# INFO:root:Step 174 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.50
# INFO:root:Step 179 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.58
# INFO:root:Step 184 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.66
# INFO:root:Step 189 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.66
# INFO:root:Step 194 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.54
# INFO:root:Step 199 of 233,	Accuracy: 1.00,	mIoU: 0.83,	Loss: 47.52
# INFO:root:Step 204 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.85
# INFO:root:Step 209 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.71
# INFO:root:Step 214 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.73
# INFO:root:Step 219 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.74
# INFO:root:Step 224 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.62
# INFO:root:Step 229 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.62
# INFO:root:Validating
# INFO:root:Training accuracy: 0.99 | Training loss: 47.68 | Training mIoU: 0.83
# INFO:root:Validation accuracy: 0.99 | Validation loss: 83.08 | Validation mIoU: 0.84
# INFO:root:Saving with loss of 83.0831298828125, improved over previous 84.20149230957031
# INFO:root:Epoch 100
# INFO:root:Training
# INFO:root:Step 4 of 233,	Accuracy: 0.99,	mIoU: 0.86,	Loss: 37.70
# INFO:root:Step 9 of 233,	Accuracy: 0.99,	mIoU: 0.87,	Loss: 41.59
# INFO:root:Step 14 of 233,	Accuracy: 1.00,	mIoU: 0.87,	Loss: 42.90
# INFO:root:Step 19 of 233,	Accuracy: 1.00,	mIoU: 0.86,	Loss: 44.35
# INFO:root:Step 24 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 47.13
# INFO:root:Step 29 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 46.88
# INFO:root:Step 34 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 47.96
# INFO:root:Step 39 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 47.18
# INFO:root:Step 44 of 233,	Accuracy: 1.00,	mIoU: 0.84,	Loss: 46.47
# INFO:root:Step 49 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.60
# INFO:root:Step 54 of 233,	Accuracy: 1.00,	mIoU: 0.85,	Loss: 49.34
# INFO:root:Step 59 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.79
# INFO:root:Step 64 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.34
# INFO:root:Step 69 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.63
# INFO:root:Step 74 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.15
# INFO:root:Step 79 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.38
# INFO:root:Step 84 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.79
# INFO:root:Step 89 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 49.60
# INFO:root:Step 94 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.49
# INFO:root:Step 99 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 49.00
# INFO:root:Step 104 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.91
# INFO:root:Step 109 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.66
# INFO:root:Step 114 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 48.59
# INFO:root:Step 119 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.72
# INFO:root:Step 124 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.19
# INFO:root:Step 129 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 47.65
# INFO:root:Step 134 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 47.95
# INFO:root:Step 139 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 47.93
# INFO:root:Step 144 of 233,	Accuracy: 0.99,	mIoU: 0.84,	Loss: 47.57
# INFO:root:Step 149 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.50
# INFO:root:Step 154 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.10
# INFO:root:Step 159 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.05
# INFO:root:Step 164 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.00
# INFO:root:Step 169 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.28
# INFO:root:Step 174 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.44
# INFO:root:Step 179 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.50
# INFO:root:Step 184 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.78
# INFO:root:Step 189 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.14
# INFO:root:Step 194 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.13
# INFO:root:Step 199 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.20
# INFO:root:Step 204 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 47.99
# INFO:root:Step 209 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.00
# INFO:root:Step 214 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.01
# INFO:root:Step 219 of 233,	Accuracy: 0.99,	mIoU: 0.83,	Loss: 48.10
# INFO:root:Step 224 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 48.06
# INFO:root:Step 229 of 233,	Accuracy: 0.99,	mIoU: 0.82,	Loss: 48.10
# INFO:root:Validating
# INFO:root:Training accuracy: 0.99 | Training loss: 48.03 | Training mIoU: 0.83
# INFO:root:Validation accuracy: 1.00 | Validation loss: 86.57 | Validation mIoU: 0.83

# %%
net.load_state_dict(torch.load("best.pth"))
# Out:
# <All keys matched successfully>

# %%
start = time.time()

test_losses, test_accuracies, test_miou = forward_pass(test_dataloader, draw=False, train=False)
total_time = time.time() - start
logging.info(f"Average inference time is: {total_time/len(test_dataloader):.3f}")
logging.info(f"Test accuracy: {sum(test_accuracies)/len(test_accuracies):.2f} | Test loss: {sum(test_losses)/len(test_losses):.2f} | Test mIoU: {sum(test_miou)/len(test_miou):.2f}")
# Out:
# INFO:root:Average inference time is: 0.041
# INFO:root:Test accuracy: 0.99 | Test loss: 56.89 | Test mIoU: 0.85
