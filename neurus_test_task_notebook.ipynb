# %%
import os
import random
import time
import copy
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from time import sleep

import torch
import cv2
import timm
from torch import nn, optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from catalyst.data.sampler import BalanceClassSampler
from ranger import Ranger
#https://github.com/lessw2020/Ranger-Deep-Learning-Optimizer
import torch.nn.functional as F
from torch.cuda.amp import autocast, GradScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
import albumentations as A
from albumentations import (
    HorizontalFlip, VerticalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine, RandomResizedCrop,
    IAASharpen, IAAEmboss, RandomBrightnessContrast, Flip, OneOf, Compose, Normalize, Cutout, ShiftScaleRotate, CenterCrop, Resize
)
from albumentations.pytorch import ToTensorV2

import logging
logging.getLogger().setLevel(logging.INFO)

import warnings
warnings.filterwarnings('ignore')

# %%
# seed everything
SEED = 55555

random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# hyperparameters
DATA_PATH = r"./data/"

IMAGE_SIZE = 250
BATCH_SIZE = 24
GRADIENT_ACCUMULATION_STEPS = 5
LEARNING_RATE = 0.0005
EPOCHS = 100
N_CLASS = 2
LAMBDA = 30

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    logging.info(f"Running on {torch.cuda.get_device_name()}")
else:
    device = torch.device("cpu")
    logging.info("Running on a CPU")
# Out:
# INFO:root:Running on GeForce GTX 1060 6GB

# %%
content_list = []
labels_list = []

for image in tqdm_notebook(os.listdir(DATA_PATH)):    
    if ".jpg" in image:
        content = cv2.imread(DATA_PATH + image)
        content = cv2.cvtColor(content, cv2.COLOR_BGR2RGB)        
        content = np.array(content)
        content_list.append(content)
    elif ".txt" in image:
        with open(DATA_PATH + image, 'r') as f:
            labels = f.read()
        labels = np.array(labels.split(" "), dtype=int)
        labels[0] = 0 if labels[0] == 1 else 1
        labels = np.roll(labels, -1)   
        labels_list.append(labels)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6770.0), HTML(value='')))

# %%
dataset = np.array([list(a) for a in zip(content_list, labels_list)])

# %%
train_dataset, test_dataset = train_test_split(dataset, shuffle=True, test_size=0.1, random_state=SEED)
train_dataset, valid_dataset = train_test_split(train_dataset, shuffle=True, test_size=0.2, random_state=SEED)
train_clf_labels = [a[-1] for a in train_dataset[:,1]]

# %%
# custom dataset class that augments data during training
# imagenet normalization is used for efficientnet fine-tuning

class Dataset(torch.utils.data.Dataset):
    def __init__(self, dataset, transforms=None):
        super().__init__()
        self.data = dataset
        self.transforms = transforms

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        image, label = self.data[index][0], self.data[index][1]
        if image.shape[-1] == 4:
            # removing alpha channel if present
            image = image[..., :3]
        if len(image.shape) == 2:
            # converting single channel image to 3 channel for possible greyscales
            image = np.stack((image,)  * 3, axis = -1)

        if self.transforms is not None:
            # bboxes=[labels] labels are wrapped into list for correct augmentation
            transformed = self.transforms(image=image, bboxes=[label])

            image = transformed["image"]
            label = torch.Tensor(transformed["bboxes"])[0]

        return image, label

transform = Compose([
            Resize(width=IMAGE_SIZE, height=IMAGE_SIZE),
            HorizontalFlip(p=0.4),
            ShiftScaleRotate(p=0.3),
            MedianBlur(blur_limit=7, always_apply=False, p=0.3),
            IAAAdditiveGaussianNoise(scale=(0, 0.15*255), p=0.5),
            HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.4),
            RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), p=0.5),
            # in this implementation imagenet normalization is used            
            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, p=1.0),
            Cutout(p=0.4),
            ToTensorV2(p=1.0),
        ], p=1.0, bbox_params=A.BboxParams(format='pascal_voc'))

test_transform = Compose([
            # only resize and normalization is used for testing
            # no TTA is implemented in this solution
            Resize(width=IMAGE_SIZE, height=IMAGE_SIZE),                    
            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, p=1.0),
            ToTensorV2(p=1.0),
        ], p=1.0, bbox_params=A.BboxParams(format='pascal_voc'))


train_dataset, valid_dataset = Dataset(train_dataset, transforms = transform), Dataset(valid_dataset, transforms = transform)
test_dataset = Dataset(test_dataset, transforms = test_transform)

# %%
train_dataloader = DataLoader(
            train_dataset,
            #balanced sampler is used to minimize harmful effects of dataset not being fully balanced
            sampler=BalanceClassSampler(labels=train_clf_labels, mode="upsampling"),
            #sampler = RandomSampler(train_dataset),
            batch_size = BATCH_SIZE)
valid_dataloader = DataLoader(
            valid_dataset,
            sampler = SequentialSampler(valid_dataset),
            batch_size = BATCH_SIZE)
test_dataloader = DataLoader(
            test_dataset,
            sampler = SequentialSampler(test_dataset),
            batch_size = 1)

# %%
# class EFN_Classifier(nn.Module):
#     def __init__(self, model_arch, n_class, pretrained=True):
#         super().__init__()
#         self.model = timm.create_model(model_arch, pretrained=pretrained)
#         n_features = self.model.classifier.in_features
#         self.model.classifier = nn.Linear(n_features, 2048)

#         self.fc1 = nn.Linear(2048, 1536)
#         self.fc2 = nn.Linear(2048, 512)

#         self.dropout = nn.Dropout(0.35)

#         self.fc_bbox = nn.Linear(1536, 4)
#         self.fc_clf = nn.Linear(512, n_class)
        
#     def forward(self, x):
#         x = self.model(x)
#         x = self.dropout(x)

#         x_bbox = self.fc1(x)
#         x_bbox = self.dropout(x_bbox)

#         x = self.fc2(x)
#         x = self.dropout(x)

#         x_bbox = self.fc_bbox(x_bbox)
#         x = self.fc_clf(x)

#         return x, x_bbox

# net = EFN_Classifier("tf_efficientnet_b1_ns", N_CLASS).to(device)
# EfficientNet: https://arxiv.org/abs/1905.11946
# fine tuning the efficientnet for classification and object detection
# in this implementation, no weights are frozen
# ideally, batchnorm layers can be frozen for marginal training speed increase

# %%
class EFN_Simple_Classifier(nn.Module):
    def __init__(self, n_class):
        super(EFN_Simple_Classifier, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=2, padding=0)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=2)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, padding=2)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=5, padding=2)
        self.bn4 = nn.BatchNorm2d(256)
        self.conv5 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=5, padding=2)
        self.bn5 = nn.BatchNorm2d(512)
        self.conv6 = nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=5, padding=2)
        self.bn6 = nn.BatchNorm2d(1024)
        self.conv7 = nn.Conv2d(in_channels=1024, out_channels=2048, kernel_size=5, padding=2)
        self.bn7 = nn.BatchNorm2d(2048)

        self.pool = nn.AvgPool2d(2)

        self.fc1 = nn.Linear(2048, 2048)

        self.dropout = nn.Dropout(0.15)

        self.fc_bbox = nn.Linear(2048, 4)
        self.fc_clf = nn.Linear(2048, n_class)

    def mish(self, x):
        return x * torch.tanh(F.softplus(x))
        
    def forward(self, x):

        x = self.pool(self.mish(self.bn1(self.conv1(x)))) 
        x = self.dropout(self.pool(self.mish(self.bn2(self.conv2(x)))))
        x = self.dropout(self.pool(self.mish(self.bn3(self.conv3(x)))))
        x = self.dropout(self.pool(self.mish(self.bn4(self.conv4(x)))))
        x = self.dropout(self.pool(self.mish(self.bn5(self.conv5(x)))))
        x = self.dropout(self.pool(self.mish(self.bn6(self.conv6(x)))))
        x = self.dropout(self.pool(self.mish(self.bn7(self.conv7(x)))))
        #print(x.size())
        x = torch.flatten(x, 1)
        #print(x.size())        
        x_clf = self.fc_clf(x)
        x_bbox = self.fc1(x)
        x_bbox = self.fc_bbox(x_bbox)

        return x_clf, x_bbox

net = EFN_Simple_Classifier(N_CLASS).to(device)

# %%
loss_function = nn.MSELoss()
clf_loss_function = nn.CrossEntropyLoss()
#optimizer = Ranger(net.parameters(), lr=LEARNING_RATE, weight_decay = 0.999, betas = (0.9, 0.999))
optimizer = torch.optim.AdamW(net.parameters(), lr=LEARNING_RATE, betas=(0.9, 0.999), weight_decay=0.999)
scheduler = CosineAnnealingLR(optimizer, EPOCHS * 0.25, LEARNING_RATE * 0.0001)
scheduler.last_epoch = EPOCHS
scaler = GradScaler()

def training_loop():
    best_model_wts = copy.deepcopy(net.state_dict())
    best_loss = float("inf")
    
    for epoch in (range(EPOCHS)):        
        if epoch != 0 and epoch > 0.25 * EPOCHS: # cosine anneal the last 25% of epochs
            scheduler.step()
        logging.info(f"Epoch {epoch+1}")

        logging.info("Training")
        train_losses, train_accuracies, train_miou = forward_pass(train_dataloader, train = True)  

        logging.info("Validating")
        val_losses, val_accuracies, val_miou = forward_pass(valid_dataloader)

        logging.info(f"Training accuracy:   {sum(train_accuracies)/len(train_accuracies):.2f} | Training loss: {sum(train_losses)/len(train_losses):.2f} | Training mIoU: {sum(train_miou)/len(train_miou):.2f}")
        logging.info(f"Validation accuracy: {sum(val_accuracies)/len(val_accuracies):.2f} | Validation loss: {sum(val_losses)/len(val_losses):.2f} | Validation mIoU: {sum(val_miou)/len(val_miou):.2f}")
        
        epoch_val_loss = sum(val_losses)/len(val_losses)
        
        if best_loss > epoch_val_loss:    
            best_loss = epoch_val_loss
            best_model_wts = copy.deepcopy(net.state_dict())
            torch.save(net.state_dict(), "best.pth")
            logging.info(f"Saving with loss of {epoch_val_loss}, improved over previous {best_loss}")

# %%
def bbox_iou(true_boxes, pred_boxes):
    iou_list = []    
    for true_box, pred_box in zip(true_boxes, pred_boxes):        

        x_left = max(true_box[0], pred_box[0]).item()
        y_top = max(true_box[1], pred_box[1]).item()

        x_right = min(true_box[2], pred_box[2]).item()
        y_bottom = min(true_box[3], pred_box[3]).item()

        if x_right < x_left or y_bottom < y_top:
            return 0.0 

        overlap = (x_right - x_left) * (y_bottom - y_top)

        true_box_area = (true_box[2] - true_box[0]) * (true_box[3] - true_box[1])
        pred_box_area = (pred_box[2] - pred_box[0]) * (pred_box[3] - pred_box[1])
        iou = overlap / float(true_box_area + pred_box_area - overlap)        
        iou_list.append(iou)
    
    iou = torch.tensor(iou)
    iou = torch.mean(iou)    

    return iou

def draw_boxes(images, bboxes, labels):        
        label_dict = {0 : "Cat", 1 : "Dog"}

        for batch in zip(images, bboxes, labels):
                cv2.destroyAllWindows()
                image, bbox, label = batch[0].cpu().numpy(), batch[1].cpu().numpy(), torch.argmax(batch[2]).cpu().item()
                image = np.rollaxis(image, 0, 3)
                image = ((image - image.min()) * (1/(image.max() - image.min()) * 255)).astype('uint8')
                image = cv2.UMat(image)

                cv2.rectangle(image,
                        (bbox[0], bbox[1]),
                        (bbox[2], bbox[3]),
                        (0, 255, 0),
                        thickness=2)

                cv2.putText(image, f"{label_dict[label]}", (bbox[1], bbox[3]), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)
                cv2.imshow("test", image)
                cv2.waitKey(1)
                sleep(1)        


def forward_pass(dataloader, draw=False, train=False):
    if train:
        net.train()
    else:
        net.eval()

    losses = []
    accuracies = []
    miou = []

    for step, batch in (enumerate(dataloader)):
        inputs = batch[0].to(device).float()
        labels = batch[1].to(device).float()
        
        # splitting labels for separate loss calculation
        bbox_labels = labels[:, :4] 
        clf_labels = labels[:, 4:].long()
        clf_labels = clf_labels[:,0]       

        with autocast():
            if train:
                label_outputs, bbox_outputs = net(inputs)
                bbox_loss = loss_function(bbox_outputs, bbox_labels)                
                clf_loss = clf_loss_function(label_outputs, clf_labels)

                loss = torch.mean(bbox_loss + clf_loss*LAMBDA)
                scaler.scale(loss).backward()
            else:
                with torch.no_grad():
                    label_outputs, bbox_outputs = net(inputs)
                    bbox_loss = loss_function(bbox_outputs, bbox_labels)                
                    clf_loss = clf_loss_function(label_outputs, clf_labels)
                    loss = torch.mean(bbox_loss + clf_loss*LAMBDA)
        if draw:
            draw_boxes(inputs, bbox_outputs, label_outputs)
        
        matches = [torch.argmax(i) == j for i, j in zip(label_outputs, clf_labels)] 
        acc = matches.count(True)/len(matches)
        iou = bbox_iou(bbox_labels, bbox_outputs)

        miou.append(iou)
        losses.append(loss)
        accuracies.append(acc)
        
        if train and (step+1) % GRADIENT_ACCUMULATION_STEPS == 0:
        # gradient accumulation to train with bigger effective batch size 
        # with less memory use
        # fp16 is used to speed up training and reduce memory consumption
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()            
            logging.info(f"Step {step} of {len(train_dataloader)},\t"\
                            f"Accuracy: {sum(accuracies)/len(accuracies):.2f},\t"\
                            f"mIoU: {sum(miou)/len(miou):.2f},\t"\
                            f"Loss: {sum(losses)/len(losses):.2f}")

    return losses, accuracies, miou

# %%
training_loop()
# Out:
# INFO:root:Epoch 1
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.41,	mIoU: 0.00,	Loss: 16737.21
# INFO:root:Step 9 of 140,	Accuracy: 0.45,	mIoU: 0.00,	Loss: 16785.74
# INFO:root:Step 14 of 140,	Accuracy: 0.48,	mIoU: 0.00,	Loss: 16825.61
# INFO:root:Step 19 of 140,	Accuracy: 0.48,	mIoU: 0.00,	Loss: 16895.94
# INFO:root:Step 24 of 140,	Accuracy: 0.48,	mIoU: 0.00,	Loss: 16940.50
# INFO:root:Step 29 of 140,	Accuracy: 0.49,	mIoU: 0.00,	Loss: 16785.81
# INFO:root:Step 34 of 140,	Accuracy: 0.50,	mIoU: 0.00,	Loss: 16704.66
# INFO:root:Step 39 of 140,	Accuracy: 0.49,	mIoU: 0.00,	Loss: 16763.71
# INFO:root:Step 44 of 140,	Accuracy: 0.50,	mIoU: 0.00,	Loss: 16624.22
# INFO:root:Step 49 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 16389.11
# INFO:root:Step 54 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 16232.79
# INFO:root:Step 59 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 15990.52
# INFO:root:Step 64 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 15700.86
# INFO:root:Step 69 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 15389.06
# INFO:root:Step 74 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 14933.59
# INFO:root:Step 79 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 14447.66
# INFO:root:Step 84 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 13903.43
# INFO:root:Step 89 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 13361.55
# INFO:root:Step 94 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 12788.65
# INFO:root:Step 99 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 12255.97
# INFO:root:Step 104 of 140,	Accuracy: 0.52,	mIoU: 0.00,	Loss: 11776.84
# INFO:root:Step 109 of 140,	Accuracy: 0.52,	mIoU: 0.01,	Loss: 11327.12
# INFO:root:Step 114 of 140,	Accuracy: 0.52,	mIoU: 0.02,	Loss: 10927.93
# INFO:root:Step 119 of 140,	Accuracy: 0.52,	mIoU: 0.03,	Loss: 10585.30
# INFO:root:Step 124 of 140,	Accuracy: 0.52,	mIoU: 0.04,	Loss: 10270.43
# INFO:root:Step 129 of 140,	Accuracy: 0.52,	mIoU: 0.05,	Loss: 9971.97
# INFO:root:Step 134 of 140,	Accuracy: 0.52,	mIoU: 0.06,	Loss: 9670.30
# INFO:root:Step 139 of 140,	Accuracy: 0.52,	mIoU: 0.07,	Loss: 9380.91
# INFO:root:Validating
# INFO:root:Training accuracy:   0.52 | Training loss: 9380.91 | Training mIoU: 0.07
# INFO:root:Validation accuracy: 0.45 | Validation loss: 1746.52 | Validation mIoU: 0.33
# INFO:root:Saving with loss of 1746.5184326171875, improved over previous 1746.5184326171875
# INFO:root:Epoch 2
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.62,	mIoU: 0.26,	Loss: 2166.33
# INFO:root:Step 9 of 140,	Accuracy: 0.55,	mIoU: 0.24,	Loss: 2287.56
# INFO:root:Step 14 of 140,	Accuracy: 0.53,	mIoU: 0.18,	Loss: 2206.40
# INFO:root:Step 19 of 140,	Accuracy: 0.54,	mIoU: 0.22,	Loss: 2070.52
# INFO:root:Step 24 of 140,	Accuracy: 0.52,	mIoU: 0.26,	Loss: 1965.56
# INFO:root:Step 29 of 140,	Accuracy: 0.52,	mIoU: 0.30,	Loss: 1887.47
# INFO:root:Step 34 of 140,	Accuracy: 0.52,	mIoU: 0.32,	Loss: 1845.37
# INFO:root:Step 39 of 140,	Accuracy: 0.52,	mIoU: 0.33,	Loss: 1831.69
# INFO:root:Step 44 of 140,	Accuracy: 0.52,	mIoU: 0.31,	Loss: 1821.94
# INFO:root:Step 49 of 140,	Accuracy: 0.53,	mIoU: 0.31,	Loss: 1789.14
# INFO:root:Step 54 of 140,	Accuracy: 0.52,	mIoU: 0.30,	Loss: 1781.52
# INFO:root:Step 59 of 140,	Accuracy: 0.52,	mIoU: 0.29,	Loss: 1755.69
# INFO:root:Step 64 of 140,	Accuracy: 0.52,	mIoU: 0.28,	Loss: 1731.03
# INFO:root:Step 69 of 140,	Accuracy: 0.51,	mIoU: 0.26,	Loss: 1722.00
# INFO:root:Step 74 of 140,	Accuracy: 0.51,	mIoU: 0.25,	Loss: 1700.47
# INFO:root:Step 79 of 140,	Accuracy: 0.51,	mIoU: 0.24,	Loss: 1705.61
# INFO:root:Step 84 of 140,	Accuracy: 0.51,	mIoU: 0.23,	Loss: 1699.44
# INFO:root:Step 89 of 140,	Accuracy: 0.51,	mIoU: 0.22,	Loss: 1690.26
# INFO:root:Step 94 of 140,	Accuracy: 0.51,	mIoU: 0.22,	Loss: 1688.09
# INFO:root:Step 99 of 140,	Accuracy: 0.51,	mIoU: 0.22,	Loss: 1680.58
# INFO:root:Step 104 of 140,	Accuracy: 0.51,	mIoU: 0.22,	Loss: 1674.29
# INFO:root:Step 109 of 140,	Accuracy: 0.51,	mIoU: 0.22,	Loss: 1669.16
# INFO:root:Step 114 of 140,	Accuracy: 0.51,	mIoU: 0.22,	Loss: 1661.80
# INFO:root:Step 119 of 140,	Accuracy: 0.51,	mIoU: 0.22,	Loss: 1660.55
# INFO:root:Step 124 of 140,	Accuracy: 0.51,	mIoU: 0.22,	Loss: 1655.56
# INFO:root:Step 129 of 140,	Accuracy: 0.51,	mIoU: 0.24,	Loss: 1643.88
# INFO:root:Step 134 of 140,	Accuracy: 0.51,	mIoU: 0.24,	Loss: 1628.84
# INFO:root:Step 139 of 140,	Accuracy: 0.51,	mIoU: 0.24,	Loss: 1627.08
# INFO:root:Validating
# INFO:root:Training accuracy:   0.51 | Training loss: 1627.08 | Training mIoU: 0.24
# INFO:root:Validation accuracy: 0.52 | Validation loss: 1513.13 | Validation mIoU: 0.29
# INFO:root:Saving with loss of 1513.1343994140625, improved over previous 1513.1343994140625
# INFO:root:Epoch 3
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.52,	mIoU: 0.45,	Loss: 1451.43
# INFO:root:Step 9 of 140,	Accuracy: 0.47,	mIoU: 0.33,	Loss: 1484.53
# INFO:root:Step 14 of 140,	Accuracy: 0.48,	mIoU: 0.32,	Loss: 1505.41
# INFO:root:Step 19 of 140,	Accuracy: 0.49,	mIoU: 0.33,	Loss: 1482.50
# INFO:root:Step 24 of 140,	Accuracy: 0.49,	mIoU: 0.31,	Loss: 1488.44
# INFO:root:Step 29 of 140,	Accuracy: 0.49,	mIoU: 0.29,	Loss: 1523.90
# INFO:root:Step 34 of 140,	Accuracy: 0.49,	mIoU: 0.27,	Loss: 1513.09
# INFO:root:Step 39 of 140,	Accuracy: 0.49,	mIoU: 0.28,	Loss: 1498.44
# INFO:root:Step 44 of 140,	Accuracy: 0.48,	mIoU: 0.28,	Loss: 1489.08
# INFO:root:Step 49 of 140,	Accuracy: 0.48,	mIoU: 0.31,	Loss: 1476.04
# INFO:root:Step 54 of 140,	Accuracy: 0.48,	mIoU: 0.30,	Loss: 1475.24
# INFO:root:Step 59 of 140,	Accuracy: 0.49,	mIoU: 0.28,	Loss: 1485.30
# INFO:root:Step 64 of 140,	Accuracy: 0.49,	mIoU: 0.28,	Loss: 1487.14
# INFO:root:Step 69 of 140,	Accuracy: 0.49,	mIoU: 0.27,	Loss: 1505.25
# INFO:root:Step 74 of 140,	Accuracy: 0.50,	mIoU: 0.27,	Loss: 1508.36
# INFO:root:Step 79 of 140,	Accuracy: 0.50,	mIoU: 0.28,	Loss: 1501.39
# INFO:root:Step 84 of 140,	Accuracy: 0.50,	mIoU: 0.27,	Loss: 1517.20
# INFO:root:Step 89 of 140,	Accuracy: 0.50,	mIoU: 0.28,	Loss: 1510.76
# INFO:root:Step 94 of 140,	Accuracy: 0.50,	mIoU: 0.29,	Loss: 1501.16
# INFO:root:Step 99 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1505.04
# INFO:root:Step 104 of 140,	Accuracy: 0.51,	mIoU: 0.28,	Loss: 1508.46
# INFO:root:Step 109 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1503.76
# INFO:root:Step 114 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1504.68
# INFO:root:Step 119 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1513.06
# INFO:root:Step 124 of 140,	Accuracy: 0.51,	mIoU: 0.28,	Loss: 1521.32
# INFO:root:Step 129 of 140,	Accuracy: 0.51,	mIoU: 0.28,	Loss: 1519.48
# INFO:root:Step 134 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1506.70
# INFO:root:Step 139 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1497.48
# INFO:root:Validating
# INFO:root:Training accuracy:   0.51 | Training loss: 1497.48 | Training mIoU: 0.29
# INFO:root:Validation accuracy: 0.40 | Validation loss: 1509.53 | Validation mIoU: 0.30
# INFO:root:Saving with loss of 1509.5347900390625, improved over previous 1509.5347900390625
# INFO:root:Epoch 4
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.53,	mIoU: 0.36,	Loss: 1412.88
# INFO:root:Step 9 of 140,	Accuracy: 0.52,	mIoU: 0.38,	Loss: 1337.57
# INFO:root:Step 14 of 140,	Accuracy: 0.51,	mIoU: 0.38,	Loss: 1356.47
# INFO:root:Step 19 of 140,	Accuracy: 0.49,	mIoU: 0.36,	Loss: 1385.97
# INFO:root:Step 24 of 140,	Accuracy: 0.48,	mIoU: 0.36,	Loss: 1393.02
# INFO:root:Step 29 of 140,	Accuracy: 0.48,	mIoU: 0.34,	Loss: 1401.13
# INFO:root:Step 34 of 140,	Accuracy: 0.48,	mIoU: 0.32,	Loss: 1405.28
# INFO:root:Step 39 of 140,	Accuracy: 0.48,	mIoU: 0.34,	Loss: 1374.35
# INFO:root:Step 44 of 140,	Accuracy: 0.50,	mIoU: 0.33,	Loss: 1379.26
# INFO:root:Step 49 of 140,	Accuracy: 0.50,	mIoU: 0.32,	Loss: 1383.61
# INFO:root:Step 54 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1389.22
# INFO:root:Step 59 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1380.70
# INFO:root:Step 64 of 140,	Accuracy: 0.50,	mIoU: 0.30,	Loss: 1392.34
# INFO:root:Step 69 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1394.78
# INFO:root:Step 74 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1393.00
# INFO:root:Step 79 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1403.52
# INFO:root:Step 84 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1408.90
# INFO:root:Step 89 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1393.27
# INFO:root:Step 94 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1401.11
# INFO:root:Step 99 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1402.39
# INFO:root:Step 104 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1409.46
# INFO:root:Step 109 of 140,	Accuracy: 0.50,	mIoU: 0.31,	Loss: 1407.06
# INFO:root:Step 114 of 140,	Accuracy: 0.51,	mIoU: 0.31,	Loss: 1404.94
# INFO:root:Step 119 of 140,	Accuracy: 0.51,	mIoU: 0.30,	Loss: 1410.67
# INFO:root:Step 124 of 140,	Accuracy: 0.51,	mIoU: 0.30,	Loss: 1407.20
# INFO:root:Step 129 of 140,	Accuracy: 0.51,	mIoU: 0.30,	Loss: 1399.89
# INFO:root:Step 134 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1403.11
# INFO:root:Step 139 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1406.12
# INFO:root:Validating
# INFO:root:Training accuracy:   0.51 | Training loss: 1406.12 | Training mIoU: 0.29
# INFO:root:Validation accuracy: 0.63 | Validation loss: 1425.17 | Validation mIoU: 0.25
# INFO:root:Saving with loss of 1425.172119140625, improved over previous 1425.172119140625
# INFO:root:Epoch 5
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.51,	mIoU: 0.11,	Loss: 1511.38
# INFO:root:Step 9 of 140,	Accuracy: 0.54,	mIoU: 0.12,	Loss: 1554.85
# INFO:root:Step 14 of 140,	Accuracy: 0.54,	mIoU: 0.12,	Loss: 1519.94
# INFO:root:Step 19 of 140,	Accuracy: 0.54,	mIoU: 0.11,	Loss: 1485.86
# INFO:root:Step 24 of 140,	Accuracy: 0.54,	mIoU: 0.15,	Loss: 1447.39
# INFO:root:Step 29 of 140,	Accuracy: 0.52,	mIoU: 0.19,	Loss: 1411.66
# INFO:root:Step 34 of 140,	Accuracy: 0.53,	mIoU: 0.20,	Loss: 1438.25
# INFO:root:Step 39 of 140,	Accuracy: 0.52,	mIoU: 0.21,	Loss: 1423.34
# INFO:root:Step 44 of 140,	Accuracy: 0.52,	mIoU: 0.22,	Loss: 1419.72
# INFO:root:Step 49 of 140,	Accuracy: 0.52,	mIoU: 0.24,	Loss: 1416.98
# INFO:root:Step 54 of 140,	Accuracy: 0.52,	mIoU: 0.25,	Loss: 1428.66
# INFO:root:Step 59 of 140,	Accuracy: 0.52,	mIoU: 0.24,	Loss: 1415.42
# INFO:root:Step 64 of 140,	Accuracy: 0.52,	mIoU: 0.24,	Loss: 1415.75
# INFO:root:Step 69 of 140,	Accuracy: 0.52,	mIoU: 0.25,	Loss: 1411.36
# INFO:root:Step 74 of 140,	Accuracy: 0.52,	mIoU: 0.26,	Loss: 1421.73
# INFO:root:Step 79 of 140,	Accuracy: 0.52,	mIoU: 0.27,	Loss: 1412.23
# INFO:root:Step 84 of 140,	Accuracy: 0.51,	mIoU: 0.28,	Loss: 1407.36
# INFO:root:Step 89 of 140,	Accuracy: 0.51,	mIoU: 0.28,	Loss: 1404.76
# INFO:root:Step 94 of 140,	Accuracy: 0.51,	mIoU: 0.27,	Loss: 1401.30
# INFO:root:Step 99 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1403.11
# INFO:root:Step 104 of 140,	Accuracy: 0.52,	mIoU: 0.28,	Loss: 1407.33
# INFO:root:Step 109 of 140,	Accuracy: 0.52,	mIoU: 0.28,	Loss: 1409.97
# INFO:root:Step 114 of 140,	Accuracy: 0.52,	mIoU: 0.29,	Loss: 1403.22
# INFO:root:Step 119 of 140,	Accuracy: 0.51,	mIoU: 0.28,	Loss: 1405.51
# INFO:root:Step 124 of 140,	Accuracy: 0.52,	mIoU: 0.29,	Loss: 1409.85
# INFO:root:Step 129 of 140,	Accuracy: 0.51,	mIoU: 0.29,	Loss: 1407.02
# INFO:root:Step 134 of 140,	Accuracy: 0.51,	mIoU: 0.30,	Loss: 1405.60
# INFO:root:Step 139 of 140,	Accuracy: 0.51,	mIoU: 0.30,	Loss: 1404.11
# INFO:root:Validating
# INFO:root:Training accuracy:   0.51 | Training loss: 1404.11 | Training mIoU: 0.30
# INFO:root:Validation accuracy: 0.37 | Validation loss: 1413.79 | Validation mIoU: 0.30
# INFO:root:Saving with loss of 1413.7906494140625, improved over previous 1413.7906494140625
# INFO:root:Epoch 6
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.55,	mIoU: 0.33,	Loss: 1235.53
# INFO:root:Step 9 of 140,	Accuracy: 0.55,	mIoU: 0.28,	Loss: 1361.51
# INFO:root:Step 14 of 140,	Accuracy: 0.55,	mIoU: 0.24,	Loss: 1400.62
# INFO:root:Step 19 of 140,	Accuracy: 0.54,	mIoU: 0.25,	Loss: 1380.18
# INFO:root:Step 24 of 140,	Accuracy: 0.54,	mIoU: 0.26,	Loss: 1358.53
# INFO:root:Step 29 of 140,	Accuracy: 0.53,	mIoU: 0.26,	Loss: 1375.62
# INFO:root:Step 34 of 140,	Accuracy: 0.53,	mIoU: 0.27,	Loss: 1357.10
# INFO:root:Step 39 of 140,	Accuracy: 0.54,	mIoU: 0.26,	Loss: 1351.11
# INFO:root:Step 44 of 140,	Accuracy: 0.54,	mIoU: 0.28,	Loss: 1333.18
# INFO:root:Step 49 of 140,	Accuracy: 0.55,	mIoU: 0.27,	Loss: 1323.28
# INFO:root:Step 54 of 140,	Accuracy: 0.55,	mIoU: 0.28,	Loss: 1328.53
# INFO:root:Step 59 of 140,	Accuracy: 0.55,	mIoU: 0.26,	Loss: 1347.50
# INFO:root:Step 64 of 140,	Accuracy: 0.55,	mIoU: 0.26,	Loss: 1357.84
# INFO:root:Step 69 of 140,	Accuracy: 0.55,	mIoU: 0.25,	Loss: 1363.67
# INFO:root:Step 74 of 140,	Accuracy: 0.55,	mIoU: 0.25,	Loss: 1360.65
# INFO:root:Step 79 of 140,	Accuracy: 0.55,	mIoU: 0.25,	Loss: 1369.16
# INFO:root:Step 84 of 140,	Accuracy: 0.54,	mIoU: 0.26,	Loss: 1375.26
# INFO:root:Step 89 of 140,	Accuracy: 0.55,	mIoU: 0.26,	Loss: 1377.73
# INFO:root:Step 94 of 140,	Accuracy: 0.55,	mIoU: 0.27,	Loss: 1374.45
# INFO:root:Step 99 of 140,	Accuracy: 0.54,	mIoU: 0.27,	Loss: 1374.69
# INFO:root:Step 104 of 140,	Accuracy: 0.54,	mIoU: 0.27,	Loss: 1378.27
# INFO:root:Step 109 of 140,	Accuracy: 0.55,	mIoU: 0.27,	Loss: 1386.39
# INFO:root:Step 114 of 140,	Accuracy: 0.55,	mIoU: 0.27,	Loss: 1384.72
# INFO:root:Step 119 of 140,	Accuracy: 0.55,	mIoU: 0.28,	Loss: 1379.82
# INFO:root:Step 124 of 140,	Accuracy: 0.55,	mIoU: 0.27,	Loss: 1375.67
# INFO:root:Step 129 of 140,	Accuracy: 0.55,	mIoU: 0.27,	Loss: 1371.55
# INFO:root:Step 134 of 140,	Accuracy: 0.55,	mIoU: 0.28,	Loss: 1367.46
# INFO:root:Step 139 of 140,	Accuracy: 0.54,	mIoU: 0.28,	Loss: 1369.37
# INFO:root:Validating
# INFO:root:Training accuracy:   0.54 | Training loss: 1369.37 | Training mIoU: 0.28
# INFO:root:Validation accuracy: 0.54 | Validation loss: 1447.10 | Validation mIoU: 0.25
# INFO:root:Epoch 7
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.58,	mIoU: 0.00,	Loss: 1543.46
# INFO:root:Step 9 of 140,	Accuracy: 0.57,	mIoU: 0.12,	Loss: 1447.31
# INFO:root:Step 14 of 140,	Accuracy: 0.57,	mIoU: 0.15,	Loss: 1446.18
# INFO:root:Step 19 of 140,	Accuracy: 0.58,	mIoU: 0.18,	Loss: 1407.30
# INFO:root:Step 24 of 140,	Accuracy: 0.59,	mIoU: 0.20,	Loss: 1400.94
# INFO:root:Step 29 of 140,	Accuracy: 0.58,	mIoU: 0.19,	Loss: 1417.97
# INFO:root:Step 34 of 140,	Accuracy: 0.58,	mIoU: 0.21,	Loss: 1381.93
# INFO:root:Step 39 of 140,	Accuracy: 0.57,	mIoU: 0.21,	Loss: 1377.66
# INFO:root:Step 44 of 140,	Accuracy: 0.56,	mIoU: 0.22,	Loss: 1377.09
# INFO:root:Step 49 of 140,	Accuracy: 0.56,	mIoU: 0.23,	Loss: 1373.31
# INFO:root:Step 54 of 140,	Accuracy: 0.56,	mIoU: 0.24,	Loss: 1355.81
# INFO:root:Step 59 of 140,	Accuracy: 0.56,	mIoU: 0.25,	Loss: 1343.29
# INFO:root:Step 64 of 140,	Accuracy: 0.57,	mIoU: 0.24,	Loss: 1358.89
# INFO:root:Step 69 of 140,	Accuracy: 0.57,	mIoU: 0.24,	Loss: 1356.31
# INFO:root:Step 74 of 140,	Accuracy: 0.57,	mIoU: 0.25,	Loss: 1345.84
# INFO:root:Step 79 of 140,	Accuracy: 0.57,	mIoU: 0.26,	Loss: 1347.74
# INFO:root:Step 84 of 140,	Accuracy: 0.57,	mIoU: 0.28,	Loss: 1345.03
# INFO:root:Step 89 of 140,	Accuracy: 0.56,	mIoU: 0.28,	Loss: 1345.33
# INFO:root:Step 94 of 140,	Accuracy: 0.56,	mIoU: 0.28,	Loss: 1349.27
# INFO:root:Step 99 of 140,	Accuracy: 0.57,	mIoU: 0.28,	Loss: 1340.59
# INFO:root:Step 104 of 140,	Accuracy: 0.56,	mIoU: 0.28,	Loss: 1337.61
# INFO:root:Step 109 of 140,	Accuracy: 0.56,	mIoU: 0.28,	Loss: 1343.09
# INFO:root:Step 114 of 140,	Accuracy: 0.56,	mIoU: 0.28,	Loss: 1343.08
# INFO:root:Step 119 of 140,	Accuracy: 0.56,	mIoU: 0.27,	Loss: 1345.36
# INFO:root:Step 124 of 140,	Accuracy: 0.56,	mIoU: 0.27,	Loss: 1348.83
# INFO:root:Step 129 of 140,	Accuracy: 0.56,	mIoU: 0.27,	Loss: 1345.61
# INFO:root:Step 134 of 140,	Accuracy: 0.56,	mIoU: 0.26,	Loss: 1347.20
# INFO:root:Step 139 of 140,	Accuracy: 0.56,	mIoU: 0.25,	Loss: 1356.74
# INFO:root:Validating
# INFO:root:Training accuracy:   0.56 | Training loss: 1356.74 | Training mIoU: 0.25
# INFO:root:Validation accuracy: 0.60 | Validation loss: 1378.22 | Validation mIoU: 0.33
# INFO:root:Saving with loss of 1378.220458984375, improved over previous 1378.220458984375
# INFO:root:Epoch 8
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.62,	mIoU: 0.27,	Loss: 1333.55
# INFO:root:Step 9 of 140,	Accuracy: 0.61,	mIoU: 0.22,	Loss: 1383.99
# INFO:root:Step 14 of 140,	Accuracy: 0.62,	mIoU: 0.25,	Loss: 1313.17
# INFO:root:Step 19 of 140,	Accuracy: 0.62,	mIoU: 0.21,	Loss: 1314.18
# INFO:root:Step 24 of 140,	Accuracy: 0.60,	mIoU: 0.22,	Loss: 1296.17
# INFO:root:Step 29 of 140,	Accuracy: 0.60,	mIoU: 0.24,	Loss: 1294.17
# INFO:root:Step 34 of 140,	Accuracy: 0.59,	mIoU: 0.23,	Loss: 1303.20
# INFO:root:Step 39 of 140,	Accuracy: 0.59,	mIoU: 0.24,	Loss: 1291.49
# INFO:root:Step 44 of 140,	Accuracy: 0.59,	mIoU: 0.25,	Loss: 1286.95
# INFO:root:Step 49 of 140,	Accuracy: 0.60,	mIoU: 0.28,	Loss: 1276.36
# INFO:root:Step 54 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1273.45
# INFO:root:Step 59 of 140,	Accuracy: 0.59,	mIoU: 0.28,	Loss: 1263.66
# INFO:root:Step 64 of 140,	Accuracy: 0.59,	mIoU: 0.28,	Loss: 1282.93
# INFO:root:Step 69 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1280.13
# INFO:root:Step 74 of 140,	Accuracy: 0.59,	mIoU: 0.26,	Loss: 1289.33
# INFO:root:Step 79 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1280.60
# INFO:root:Step 84 of 140,	Accuracy: 0.59,	mIoU: 0.26,	Loss: 1278.96
# INFO:root:Step 89 of 140,	Accuracy: 0.59,	mIoU: 0.25,	Loss: 1279.59
# INFO:root:Step 94 of 140,	Accuracy: 0.59,	mIoU: 0.25,	Loss: 1281.92
# INFO:root:Step 99 of 140,	Accuracy: 0.60,	mIoU: 0.24,	Loss: 1281.40
# INFO:root:Step 104 of 140,	Accuracy: 0.60,	mIoU: 0.25,	Loss: 1274.92
# INFO:root:Step 109 of 140,	Accuracy: 0.60,	mIoU: 0.26,	Loss: 1278.49
# INFO:root:Step 114 of 140,	Accuracy: 0.60,	mIoU: 0.26,	Loss: 1274.46
# INFO:root:Step 119 of 140,	Accuracy: 0.60,	mIoU: 0.27,	Loss: 1275.80
# INFO:root:Step 124 of 140,	Accuracy: 0.60,	mIoU: 0.26,	Loss: 1280.70
# INFO:root:Step 129 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1274.63
# INFO:root:Step 134 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1284.88
# INFO:root:Step 139 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1280.47
# INFO:root:Validating
# INFO:root:Training accuracy:   0.59 | Training loss: 1280.47 | Training mIoU: 0.27
# INFO:root:Validation accuracy: 0.62 | Validation loss: 1302.59 | Validation mIoU: 0.32
# INFO:root:Saving with loss of 1302.591064453125, improved over previous 1302.591064453125
# INFO:root:Epoch 9
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.65,	mIoU: 0.33,	Loss: 1149.64
# INFO:root:Step 9 of 140,	Accuracy: 0.65,	mIoU: 0.30,	Loss: 1263.74
# INFO:root:Step 14 of 140,	Accuracy: 0.64,	mIoU: 0.32,	Loss: 1310.49
# INFO:root:Step 19 of 140,	Accuracy: 0.61,	mIoU: 0.30,	Loss: 1263.19
# INFO:root:Step 24 of 140,	Accuracy: 0.61,	mIoU: 0.33,	Loss: 1244.59
# INFO:root:Step 29 of 140,	Accuracy: 0.60,	mIoU: 0.34,	Loss: 1233.87
# INFO:root:Step 34 of 140,	Accuracy: 0.61,	mIoU: 0.35,	Loss: 1228.96
# INFO:root:Step 39 of 140,	Accuracy: 0.61,	mIoU: 0.36,	Loss: 1234.23
# INFO:root:Step 44 of 140,	Accuracy: 0.61,	mIoU: 0.34,	Loss: 1234.50
# INFO:root:Step 49 of 140,	Accuracy: 0.62,	mIoU: 0.33,	Loss: 1239.11
# INFO:root:Step 54 of 140,	Accuracy: 0.62,	mIoU: 0.32,	Loss: 1229.10
# INFO:root:Step 59 of 140,	Accuracy: 0.62,	mIoU: 0.31,	Loss: 1238.11
# INFO:root:Step 64 of 140,	Accuracy: 0.62,	mIoU: 0.30,	Loss: 1244.01
# INFO:root:Step 69 of 140,	Accuracy: 0.61,	mIoU: 0.31,	Loss: 1244.86
# INFO:root:Step 74 of 140,	Accuracy: 0.61,	mIoU: 0.31,	Loss: 1242.13
# INFO:root:Step 79 of 140,	Accuracy: 0.60,	mIoU: 0.31,	Loss: 1240.36
# INFO:root:Step 84 of 140,	Accuracy: 0.60,	mIoU: 0.32,	Loss: 1246.62
# INFO:root:Step 89 of 140,	Accuracy: 0.59,	mIoU: 0.31,	Loss: 1250.53
# INFO:root:Step 94 of 140,	Accuracy: 0.59,	mIoU: 0.30,	Loss: 1248.54
# INFO:root:Step 99 of 140,	Accuracy: 0.59,	mIoU: 0.31,	Loss: 1242.00
# INFO:root:Step 104 of 140,	Accuracy: 0.59,	mIoU: 0.32,	Loss: 1234.80
# INFO:root:Step 109 of 140,	Accuracy: 0.59,	mIoU: 0.32,	Loss: 1233.07
# INFO:root:Step 114 of 140,	Accuracy: 0.59,	mIoU: 0.32,	Loss: 1230.00
# INFO:root:Step 119 of 140,	Accuracy: 0.59,	mIoU: 0.31,	Loss: 1228.13
# INFO:root:Step 124 of 140,	Accuracy: 0.59,	mIoU: 0.31,	Loss: 1230.20
# INFO:root:Step 129 of 140,	Accuracy: 0.59,	mIoU: 0.30,	Loss: 1228.49
# INFO:root:Step 134 of 140,	Accuracy: 0.59,	mIoU: 0.30,	Loss: 1224.18
# INFO:root:Step 139 of 140,	Accuracy: 0.59,	mIoU: 0.30,	Loss: 1233.37
# INFO:root:Validating
# INFO:root:Training accuracy:   0.59 | Training loss: 1233.37 | Training mIoU: 0.30
# INFO:root:Validation accuracy: 0.59 | Validation loss: 1316.71 | Validation mIoU: 0.19
# INFO:root:Epoch 10
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.59,	mIoU: 0.19,	Loss: 1377.58
# INFO:root:Step 9 of 140,	Accuracy: 0.58,	mIoU: 0.23,	Loss: 1269.23
# INFO:root:Step 14 of 140,	Accuracy: 0.56,	mIoU: 0.23,	Loss: 1219.29
# INFO:root:Step 19 of 140,	Accuracy: 0.56,	mIoU: 0.27,	Loss: 1264.83
# INFO:root:Step 24 of 140,	Accuracy: 0.58,	mIoU: 0.26,	Loss: 1273.11
# INFO:root:Step 29 of 140,	Accuracy: 0.58,	mIoU: 0.23,	Loss: 1272.77
# INFO:root:Step 34 of 140,	Accuracy: 0.59,	mIoU: 0.24,	Loss: 1264.38
# INFO:root:Step 39 of 140,	Accuracy: 0.59,	mIoU: 0.24,	Loss: 1257.93
# INFO:root:Step 44 of 140,	Accuracy: 0.58,	mIoU: 0.25,	Loss: 1255.57
# INFO:root:Step 49 of 140,	Accuracy: 0.57,	mIoU: 0.24,	Loss: 1247.66
# INFO:root:Step 54 of 140,	Accuracy: 0.58,	mIoU: 0.23,	Loss: 1248.34
# INFO:root:Step 59 of 140,	Accuracy: 0.58,	mIoU: 0.23,	Loss: 1231.94
# INFO:root:Step 64 of 140,	Accuracy: 0.58,	mIoU: 0.23,	Loss: 1245.20
# INFO:root:Step 69 of 140,	Accuracy: 0.58,	mIoU: 0.25,	Loss: 1236.11
# INFO:root:Step 74 of 140,	Accuracy: 0.58,	mIoU: 0.25,	Loss: 1228.98
# INFO:root:Step 79 of 140,	Accuracy: 0.58,	mIoU: 0.26,	Loss: 1232.84
# INFO:root:Step 84 of 140,	Accuracy: 0.59,	mIoU: 0.26,	Loss: 1234.11
# INFO:root:Step 89 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1229.12
# INFO:root:Step 94 of 140,	Accuracy: 0.58,	mIoU: 0.27,	Loss: 1220.03
# INFO:root:Step 99 of 140,	Accuracy: 0.59,	mIoU: 0.28,	Loss: 1205.04
# INFO:root:Step 104 of 140,	Accuracy: 0.59,	mIoU: 0.28,	Loss: 1207.54
# INFO:root:Step 109 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1216.02
# INFO:root:Step 114 of 140,	Accuracy: 0.58,	mIoU: 0.27,	Loss: 1210.10
# INFO:root:Step 119 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1209.53
# INFO:root:Step 124 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 1204.38
# INFO:root:Step 129 of 140,	Accuracy: 0.59,	mIoU: 0.27,	Loss: 
of 140,	Accuracy: 0.61,	mIoU: 0.36,	Loss: 1025.04
# INFO:root:Step 49 of 140,	Accuracy: 0.61,	mIoU: 0.39,	Loss: 1019.25
# INFO:root:Step 54 of 140,	Accuracy: 0.61,	mIoU: 0.37,	Loss: 1033.63
# INFO:root:Step 59 of 140,	Accuracy: 0.60,	mIoU: 0.36,	Loss: 1022.44
# INFO:root:Step 64 of 140,	Accuracy: 0.61,	mIoU: 0.36,	Loss: 1021.12
# INFO:root:Step 69 of 140,	Accuracy: 0.61,	mIoU: 0.36,	Loss: 1018.03
# INFO:root:Step 74 of 140,	Accuracy: 0.61,	mIoU: 0.35,	Loss: 1021.83
# INFO:root:Step 79 of 140,	Accuracy: 0.61,	mIoU: 0.35,	Loss: 1014.81
# INFO:root:Step 84 of 140,	Accuracy: 0.61,	mIoU: 0.36,	Loss: 1006.12
# INFO:root:Step 89 of 140,	Accuracy: 0.61,	mIoU: 0.36,	Loss: 1011.94
# INFO:root:Step 94 of 140,	Accuracy: 0.61,	mIoU: 0.36,	Loss: 1010.24
# INFO:root:Step 99 of 140,	Accuracy: 0.61,	mIoU: 0.35,	Loss: 1013.76
# INFO:root:Step 104 of 140,	Accuracy: 0.61,	mIoU: 0.36,	Loss: 1017.13
# INFO:root:Step 109 of 140,	Accuracy: 0.62,	mIoU: 0.36,	Loss: 1017.92
# INFO:root:Step 114 of 140,	Accuracy: 0.62,	mIoU: 0.35,	Loss: 1019.02
# INFO:root:Step 119 of 140,	Accuracy: 0.62,	mIoU: 0.34,	Loss: 1022.16
# INFO:root:Step 124 of 140,	Accuracy: 0.62,	mIoU: 0.35,	Loss: 1019.08
# INFO:root:Step 129 of 140,	Accuracy: 0.62,	mIoU: 0.34,	Loss: 1025.49
# INFO:root:Step 134 of 140,	Accuracy: 0.62,	mIoU: 0.35,	Loss: 1027.51
# INFO:root:Step 139 of 140,	Accuracy: 0.62,	mIoU: 0.36,	Loss: 1025.27
# INFO:root:Validating
# INFO:root:Training accuracy:   0.62 | Training loss: 1025.27 | Training mIoU: 0.36
# INFO:root:Validation accuracy: 0.51 | Validation loss: 1125.00 | Validation mIoU: 0.30
# INFO:root:Epoch 15
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.58,	mIoU: 0.17,	Loss: 1138.67
# INFO:root:Step 9 of 140,	Accuracy: 0.57,	mIoU: 0.20,	Loss: 1106.50
# INFO:root:Step 14 of 140,	Accuracy: 0.57,	mIoU: 0.22,	Loss: 1112.30
# INFO:root:Step 19 of 140,	Accuracy: 0.59,	mIoU: 0.22,	Loss: 1083.63
# INFO:root:Step 24 of 140,	Accuracy: 0.58,	mIoU: 0.28,	Loss: 1088.59
# INFO:root:Step 29 of 140,	Accuracy: 0.60,	mIoU: 0.31,	Loss: 1083.15
# INFO:root:Step 34 of 140,	Accuracy: 0.60,	mIoU: 0.33,	Loss: 1076.22
# INFO:root:Step 39 of 140,	Accuracy: 0.59,	mIoU: 0.35,	Loss: 1051.00
# INFO:root:Step 44 of 140,	Accuracy: 0.60,	mIoU: 0.33,	Loss: 1081.45
# INFO:root:Step 49 of 140,	Accuracy: 0.60,	mIoU: 0.32,	Loss: 1076.76
# INFO:root:Step 54 of 140,	Accuracy: 0.60,	mIoU: 0.32,	Loss: 1082.09
# INFO:root:Step 59 of 140,	Accuracy: 0.61,	mIoU: 0.30,	Loss: 1091.70
# INFO:root:Step 64 of 140,	Accuracy: 0.61,	mIoU: 0.30,	Loss: 1080.14
# INFO:root:Step 69 of 140,	Accuracy: 0.61,	mIoU: 0.30,	Loss: 1072.62
# INFO:root:Step 74 of 140,	Accuracy: 0.61,	mIoU: 0.29,	Loss: 1072.49
# INFO:root:Step 79 of 140,	Accuracy: 0.61,	mIoU: 0.30,	Loss: 1071.32
# INFO:root:Step 84 of 140,	Accuracy: 0.61,	mIoU: 0.29,	Loss: 1072.49
# INFO:root:Step 89 of 140,	Accuracy: 0.61,	mIoU: 0.30,	Loss: 1070.44
# INFO:root:Step 94 of 140,	Accuracy: 0.61,	mIoU: 0.30,	Loss: 1069.58
# INFO:root:Step 99 of 140,	Accuracy: 0.61,	mIoU: 0.29,	Loss: 1070.76
# INFO:root:Step 104 of 140,	Accuracy: 0.61,	mIoU: 0.29,	Loss: 1067.48
# INFO:root:Step 109 of 140,	Accuracy: 0.62,	mIoU: 0.28,	Loss: 1063.62
# INFO:root:Step 114 of 140,	Accuracy: 0.61,	mIoU: 0.29,	Loss: 1068.85
# INFO:root:Step 119 of 140,	Accuracy: 0.61,	mIoU: 0.29,	Loss: 
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.65,	mIoU: 0.42,	Loss: 754.33
# INFO:root:Step 9 of 140,	Accuracy: 0.61,	mIoU: 0.33,	Loss: 845.98
# INFO:root:Step 14 of 140,	Accuracy: 0.61,	mIoU: 0.31,	Loss: 852.44
# INFO:root:Step 19 of 140,	Accuracy: 0.63,	mIoU: 0.33,	Loss: 874.37
# INFO:root:Step 24 of 140,	Accuracy: 0.65,	mIoU: 0.35,	Loss: 864.42
# INFO:root:Step 29 of 140,	Accuracy: 0.63,	mIoU: 0.34,	Loss: 858.01
# INFO:root:Step 34 of 140,	Accuracy: 0.63,	mIoU: 0.32,	Loss: 868.91
# INFO:root:Step 39 of 140,	Accuracy: 0.63,	mIoU: 0.32,	Loss: 864.95
# INFO:root:Step 44 of 140,	Accuracy: 0.63,	mIoU: 0.29,	Loss: 875.53
# INFO:root:Step 49 of 140,	Accuracy: 0.64,	mIoU: 0.29,	Loss: 865.87
# INFO:root:Step 54 of 140,	Accuracy: 0.64,	mIoU: 0.32,	Loss: 869.77
# INFO:root:Step 59 of 140,	Accuracy: 0.64,	mIoU: 0.33,	Loss: 868.70
# INFO:root:Step 64 of 140,	Accuracy: 0.64,	mIoU: 0.34,	Loss: 869.72
# INFO:root:Step 69 of 140,	Accuracy: 0.64,	mIoU: 0.35,	Loss: 859.77
# INFO:root:Step 74 of 140,	Accuracy: 0.64,	mIoU: 0.35,	Loss: 869.27
# INFO:root:Step 79 of 140,	Accuracy: 0.64,	mIoU: 0.35,	Loss: 887.00
# INFO:root:Step 84 of 140,	Accuracy: 0.64,	mIoU: 0.35,	Loss: 886.65
# INFO:root:Step 89 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 884.93
# INFO:root:Step 94 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 890.90
# INFO:root:Step 99 of 140,	Accuracy: 0.64,	mIoU: 0.35,	Loss: 900.44
# INFO:root:Step 104 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 894.16
# INFO:root:Step 109 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 895.72
# INFO:root:Step 114 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 899.16
# INFO:root:Step 119 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 907.21
# INFO:root:Step 124 of 140,	Accuracy: 0.63,	mIoU: 0.36,	Loss: 911.91
# INFO:root:Step 129 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 918.03
# INFO:root:Step 134 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 919.59
# INFO:root:Step 139 of 140,	Accuracy: 0.64,	mIoU: 0.35,	Loss: 924.29
# INFO:root:Validating
# INFO:root:Training accuracy:   0.64 | Training loss: 924.29 | Training mIoU: 0.35
# INFO:root:Validation accuracy: 0.58 | Validation loss: 1005.05 | Validation mIoU: 0.36
# INFO:root:Epoch 20
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.62,	mIoU: 0.24,	Loss: 969.91
# INFO:root:Step 9 of 140,	Accuracy: 0.65,	mIoU: 0.32,	Loss: 879.71
# INFO:root:Step 14 of 140,	Accuracy: 0.64,	mIoU: 0.31,	Loss: 863.09
# INFO:root:Step 19 of 140,	Accuracy: 0.63,	mIoU: 0.34,	Loss: 808.33
# INFO:root:Step 24 of 140,	Accuracy: 0.62,	mIoU: 0.31,	Loss: 871.04
# INFO:root:Step 29 of 140,	Accuracy: 0.62,	mIoU: 0.31,	Loss: 866.18
# INFO:root:Step 34 of 140,	Accuracy: 0.63,	mIoU: 0.34,	Loss: 864.69
# INFO:root:Step 39 of 140,	Accuracy: 0.63,	mIoU: 0.37,	Loss: 851.93
# INFO:root:Step 44 of 140,	Accuracy: 0.64,	mIoU: 0.37,	Loss: 851.88
# INFO:root:Step 49 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 847.33
# INFO:root:Step 54 of 140,	Accuracy: 0.64,	mIoU: 0.37,	Loss: 847.00
# INFO:root:Step 59 of 140,	Accuracy: 0.63,	mIoU: 0.38,	Loss: 850.08
# INFO:root:Step 64 of 140,	Accuracy: 0.64,	mIoU: 0.40,	Loss: 841.35
# INFO:root:Step 69 of 140,	Accuracy: 0.64,	mIoU: 0.40,	Loss: 839.59
# INFO:root:Step 74 of 140,	Accuracy: 0.64,	mIoU: 0.40,	Loss: 839.86
# INFO:root:Step 79 of 140,	Accuracy: 0.64,	mIoU: 0.41,	Loss: 839.13
# INFO:root:Step 84 of 140,	Accuracy: 0.65,	mIoU: 0.41,	Loss: 842.30
# INFO:root:Step 89 of 140,	Accuracy: 0.65,	mIoU: 0.39,	Loss: 853.80
# INFO:root:Step 94 of 140,	Accuracy: 0.65,	mIoU: 0.40,	Loss: 860.92
# INFO:root:Step 99 of 140,	Accuracy: 0.65,	mIoU: 0.41,	Loss: 861.54
# INFO:root:Step 104 of 140,	Accuracy: 0.65,	mIoU: 0.41,	Loss: 858.49
# INFO:root:Step 109 of 140,	Accuracy: 0.65,	mIoU: 0.41,	Loss: 860.80
# INFO:root:Step 114 of 140,	Accuracy: 0.65,	mIoU: 0.41,	Loss: 857.24
# INFO:root:Step 119 of 140,	Accuracy: 0.65,	mIoU: 0.41,	Loss: 857.95
# INFO:root:Step 124 of 140,	Accuracy: 0.65,	mIoU: 0.40,	Loss: 862.83
# INFO:root:Step 129 of 140,	Accuracy: 0.65,	mIoU: 0.40,	Loss: 861.65
# INFO:root:Step 134 of 140,	Accuracy: 0.65,	mIoU: 0.40,	Loss: 859.44
# INFO:root:Step 139 of 140,	Accuracy: 0.65,	mIoU: 0.39,	Loss: 862.51
# INFO:root:Validating
# INFO:root:Training accuracy:   0.65 | Training loss: 862.51 | Training mIoU: 0.39
# INFO:root:Validation accuracy: 0.68 | Validation loss: 967.59 | Validation mIoU: 0.28
# INFO:root:Epoch 21
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.62,	mIoU: 0.30,	Loss: 899.31
# INFO:root:Step 9 of 140,	Accuracy: 0.65,	mIoU: 0.35,	Loss: 860.96
# INFO:root:Step 14 of 140,	Accuracy: 0.64,	mIoU: 0.37,	Loss: 886.85
# INFO:root:Step 19 of 140,	Accuracy: 0.63,	mIoU: 0.32,	Loss: 896.04
# INFO:root:Step 24 of 140,	Accuracy: 0.63,	mIoU: 0.33,	Loss: 911.24
# INFO:root:Step 29 of 140,	Accuracy: 0.64,	mIoU: 0.36,	Loss: 898.77
# INFO:root:Step 34 of 140,	Accuracy: 0.65,	mIoU: 0.35,	Loss: 878.94
# INFO:root:Step 39 of 140,	Accuracy: 0.65,	mIoU: 0.35,	Loss: 900.71
# INFO:root:Step 44 of 140,	Accuracy: 0.65,	mIoU: 0.38,	Loss: 884.20
# INFO:root:Step 49 of 140,	Accuracy: 0.65,	mIoU: 0.40,	Loss: 878.89
# INFO:root:Step 54 of 140,	Accuracy: 0.64,	mIoU: 0.41,	Loss: 863.30
# INFO:root:Step 59 of 140,	Accuracy: 0.65,	mIoU: 0.39,	Loss: 877.53
# INFO:root:Step 64 of 140,	Accuracy: 0.65,	mIoU: 0.39,	Loss: 869.11
# INFO:root:Step 69 of 140,	Accuracy: 0.65,	mIoU: 0.39,	Loss: 861.59
# INFO:root:Step 74 of 140,	Accuracy: 0.65,	mIoU: 0.39,	Loss: 852.38
# INFO:root:Step 79 of 140,	Accuracy: 0.65,	mIoU: 0.39,	Loss: 852.67
# INFO:root:Step 84 of 140,	Accuracy: 0.65,	mIoU: 0.38,	Loss: 855.51
# INFO:root:Step 89 of 140,	Accuracy: 0.65,	mIoU: 0.38,	Loss: 848.17
# INFO:root:Step 94 of 140,	Accuracy: 0.65,	mIoU: 0.37,	Loss: 845.03
# INFO:root:Step 99 of 140,	Accuracy: 0.65,	mIoU: 0.37,	Loss: 846.01
# INFO:root:Step 104 of 140,	Accuracy: 0.65,	mIoU: 0.37,	Loss: 850.61
# INFO:root:Step 109 of 140,	Accuracy: 0.64,	mIoU: 0.37,	Loss: 848.08
# INFO:root:Step 114 of 140,	Accuracy: 0.64,	mIoU: 0.38,	Loss: 848.52
# INFO:root:Step 119 of 140,	Accuracy: 0.65,	mIoU: 0.37,	Loss: 849.21
# INFO:root:Step 124 of 140,	Accuracy: 0.65,	mIoU: 0.37,	Loss: 851.99
# INFO:root:Step 129 of 140,	Accuracy: 0.65,	mIoU: 0.37,	Loss: 852.93
# INFO:root:Step 134 of 140,	Accuracy: 0.65,	mIoU: 0.37,	Loss: 851.29
# INFO:root:Step 139 of 140,	Accuracy: 0.65,	mIoU: 0.37,	Loss: 849.03
# INFO:root:Validating
# INFO:root:Training accuracy:   0.65 | Training loss: 849.03 | Training mIoU: 0.37
# INFO:root:Validation accuracy: 0.64 | Validation loss: 986.68 | Validation mIoU: 0.25
# INFO:root:Epoch 22
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.72,	mIoU: 0.44,	Loss: 774.69
# INFO:root:Step 9 of 140,	Accuracy: 0.72,	mIoU: 0.42,	Loss: 773.13
# INFO:root:Step 14 of 140,	Accuracy: 0.71,	mIoU: 0.49,	Loss: 781.78
# INFO:root:Step 19 of 140,	Accuracy: 0.69,	mIoU: 0.43,	Loss: 783.62
# INFO:root:Step 24 of 140,	Accuracy: 0.69,	mIoU: 0.40,	Loss: 784.52
# INFO:root:Step 29 of 140,	Accuracy: 0.68,	mIoU: 0.38,	Loss: 825.61
# INFO:root:Step 34 of 140,	Accuracy: 0.68,	mIoU: 0.38,	Loss: 810.12
# INFO:root:Step 39 of 140,	Accuracy: 0.68,	mIoU: 0.38,	Loss: 816.07
# INFO:root:Step 44 of 140,	Accuracy: 0.68,	mIoU: 0.39,	Loss: 800.12
# INFO:root:Step 49 of 140,	Accuracy: 0.68,	mIoU: 0.38,	Loss: 802.78
# INFO:root:Step 54 of 140,	Accuracy: 0.67,	mIoU: 0.37,	Loss: 819.14
# INFO:root:Step 59 of 140,	Accuracy: 0.67,	mIoU: 0.37,	Loss: 820.28
# INFO:root:Step 64 of 140,	Accuracy: 0.67,	mIoU: 0.38,	Loss: 821.31
# INFO:root:Step 69 of 140,	Accuracy: 0.67,	mIoU: 0.37,	Loss: 813.16
# INFO:root:Step 74 of 140,	Accuracy: 0.67,	mIoU: 0.38,	Loss: 807.19
# INFO:root:Step 79 of 140,	Accuracy: 0.67,	mIoU: 0.38,	Loss: 803.50
# INFO:root:Step 84 of 140,	Accuracy: 0.67,	mIoU: 0.38,	Loss: 802.60
# INFO:root:Step 89 of 140,	Accuracy: 0.67,	mIoU: 0.39,	Loss: 799.72
# INFO:root:Step 94 of 140,	Accuracy: 0.67,	mIoU: 0.39,	Loss: 796.69
# INFO:root:Step 99 of 140,	Accuracy: 0.68,	mIoU: 0.38,	Loss: 801.38
# INFO:root:Step 104 of 140,	Accuracy: 0.67,	mIoU: 0.38,	Loss: 804.28
# INFO:root:Step 109 of 140,	Accuracy: 0.67,	mIoU: 0.39,	Loss: 810.97
# INFO:root:Step 114 of 140,	Accuracy: 0.67,	mIoU: 0.39,	Loss: 812.97
# INFO:root:Step 119 of 140,	Accuracy: 0.67,	mIoU: 0.39,	Loss: 811.95
# INFO:root:Step 124 of 140,	Accuracy: 0.67,	mIoU: 0.38,	Loss: 812.63
# INFO:root:Step 129 of 140,	Accuracy: 0.67,	mIoU: 0.38,	Loss: 819.02
# INFO:root:Step 134 of 140,	Accuracy: 0.66,	mIoU: 0.39,	Loss: 817.10
# INFO:root:Step 139 of 140,	Accuracy: 0.66,	mIoU: 0.38,	Loss: 825.09
# INFO:root:Validating
# INFO:root:Training accuracy:   0.66 | Training loss: 825.09 | Training mIoU: 0.38
# INFO:root:Validation accuracy: 0.57 | Validation loss: 867.31 | Validation mIoU: 0.34
# ...
# INFO:root:Validation accuracy: 0.73 | Validation loss: 582.62 | Validation mIoU: 0.39
# INFO:root:Epoch 56
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.80,	mIoU: 0.60,	Loss: 370.99
# INFO:root:Step 9 of 140,	Accuracy: 0.80,	mIoU: 0.59,	Loss: 361.69
# INFO:root:Step 14 of 140,	Accuracy: 0.79,	mIoU: 0.56,	Loss: 363.83
# INFO:root:Step 19 of 140,	Accuracy: 0.77,	mIoU: 0.55,	Loss: 373.51
# INFO:root:Step 24 of 140,	Accuracy: 0.77,	mIoU: 0.58,	Loss: 373.03
# INFO:root:Step 29 of 140,	Accuracy: 0.77,	mIoU: 0.60,	Loss: 390.24
# INFO:root:Step 34 of 140,	Accuracy: 0.78,	mIoU: 0.59,	Loss: 393.40
# INFO:root:Step 39 of 140,	Accuracy: 0.78,	mIoU: 0.58,	Loss: 404.20
# INFO:root:Step 44 of 140,	Accuracy: 0.79,	mIoU: 0.57,	Loss: 411.17
# INFO:root:Step 49 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 407.00
# INFO:root:Step 54 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 408.66
# INFO:root:Step 59 of 140,	Accuracy: 0.80,	mIoU: 0.57,	Loss: 413.31
# INFO:root:Step 64 of 140,	Accuracy: 0.80,	mIoU: 0.57,	Loss: 412.62
# INFO:root:Step 69 of 140,	Accuracy: 0.80,	mIoU: 0.57,	Loss: 411.10
# INFO:root:Step 74 of 140,	Accuracy: 0.80,	mIoU: 0.57,	Loss: 414.12
# INFO:root:Step 79 of 140,	Accuracy: 0.80,	mIoU: 0.57,	Loss: 409.30
# INFO:root:Step 84 of 140,	Accuracy: 0.80,	mIoU: 0.58,	Loss: 407.24
# INFO:root:Step 89 of 140,	Accuracy: 0.80,	mIoU: 0.58,	Loss: 409.99
# INFO:root:Step 94 of 140,	Accuracy: 0.80,	mIoU: 0.58,	Loss: 408.77
# INFO:root:Step 99 of 140,	Accuracy: 0.80,	mIoU: 0.59,	Loss: 405.50
# INFO:root:Step 104 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 402.37
# INFO:root:Step 109 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 400.04
# INFO:root:Step 114 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 402.30
# INFO:root:Step 119 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 401.00
# INFO:root:Step 124 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 401.58
# INFO:root:Step 129 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 399.82
# INFO:root:Step 134 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 398.17
# INFO:root:Step 139 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 402.00
# INFO:root:Validating
# INFO:root:Training accuracy:   0.79 | Training loss: 402.00 | Training mIoU: 0.58
# INFO:root:Validation accuracy: 0.70 | Validation loss: 593.74 | Validation mIoU: 0.49
# INFO:root:Epoch 57
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.72,	mIoU: 0.64,	Loss: 339.65
# INFO:root:Step 9 of 140,	Accuracy: 0.75,	mIoU: 0.69,	Loss: 413.11
# INFO:root:Step 14 of 140,	Accuracy: 0.77,	mIoU: 0.70,	Loss: 408.01
# INFO:root:Step 19 of 140,	Accuracy: 0.76,	mIoU: 0.63,	Loss: 427.34
# INFO:root:Step 24 of 140,	Accuracy: 0.77,	mIoU: 0.63,	Loss: 420.43
# INFO:root:Step 29 of 140,	Accuracy: 0.78,	mIoU: 0.62,	Loss: 425.17
# INFO:root:Step 34 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 417.58
# INFO:root:Step 39 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 409.36
# INFO:root:Step 44 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 401.91
# INFO:root:Step 49 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 407.90
# INFO:root:Step 54 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 395.41
# INFO:root:Step 59 of 140,	Accuracy: 0.78,	mIoU: 0.59,	Loss: 398.97
# INFO:root:Step 64 of 140,	Accuracy: 0.78,	mIoU: 0.58,	Loss: 393.25
# INFO:root:Step 69 of 140,	Accuracy: 0.78,	mIoU: 0.58,	Loss: 386.36
# INFO:root:Step 74 of 140,	Accuracy: 0.78,	mIoU: 0.58,	Loss: 390.98
# INFO:root:Step 79 of 140,	Accuracy: 0.78,	mIoU: 0.59,	Loss: 392.81
# INFO:root:Step 84 of 140,	Accuracy: 0.78,	mIoU: 0.59,	Loss: 389.72
# INFO:root:Step 89 of 140,	Accuracy: 0.78,	mIoU: 0.59,	Loss:
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.83,	mIoU: 0.57,	Loss: 539.11
# INFO:root:Step 9 of 140,	Accuracy: 0.77,	mIoU: 0.53,	Loss: 451.26
# INFO:root:Step 14 of 140,	Accuracy: 0.78,	mIoU: 0.57,	Loss: 414.10
# INFO:root:Step 19 of 140,	Accuracy: 0.77,	mIoU: 0.57,	Loss: 416.80
# INFO:root:Step 24 of 140,	Accuracy: 0.78,	mIoU: 0.56,	Loss: 423.58
# INFO:root:Step 29 of 140,	Accuracy: 0.78,	mIoU: 0.56,	Loss: 406.39
# INFO:root:Step 34 of 140,	Accuracy: 0.78,	mIoU: 0.57,	Loss: 400.97
# INFO:root:Step 39 of 140,	Accuracy: 0.78,	mIoU: 0.59,	Loss: 404.73
# INFO:root:Step 44 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 405.62
# INFO:root:Step 49 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 404.73
# INFO:root:Step 54 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 402.17
# INFO:root:Step 59 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 401.12
# INFO:root:Step 64 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 400.37
# INFO:root:Step 69 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 403.52
# INFO:root:Step 74 of 140,	Accuracy: 0.78,	mIoU: 0.59,	Loss: 406.20
# INFO:root:Step 79 of 140,	Accuracy: 0.79,	mIoU: 0.60,	Loss: 405.42
# INFO:root:Step 84 of 140,	Accuracy: 0.78,	mIoU: 0.59,	Loss: 404.56
# INFO:root:Step 89 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 402.75
# INFO:root:Step 94 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 409.39
# INFO:root:Step 99 of 140,	Accuracy: 0.79,	mIoU: 0.59,	Loss: 411.59
# INFO:root:Step 104 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 415.17
# INFO:root:Step 109 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 418.01
# INFO:root:Step 114 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 418.63
# INFO:root:Step 119 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 418.26
# INFO:root:Step 124 of 140,	Accuracy: 0.79,	mIoU: 0.57,	Loss: 416.57
# INFO:root:Step 129 of 140,	Accuracy: 0.79,	mIoU: 0.57,	Loss: 417.14
# INFO:root:Step 134 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 414.63
# INFO:root:Step 139 of 140,	Accuracy: 0.79,	mIoU: 0.58,	Loss: 411.97
# INFO:root:Validating
# INFO:root:Training accuracy:   0.79 | Training loss: 411.97 | Training mIoU: 0.58
# INFO:root:Validation accuracy: 0.75 | Validation loss: 630.81 | Validation mIoU: 0.42
# INFO:root:Epoch 62
# INFO:root:Training
# INFO:root:Step 4 of 140,	Accuracy: 0.82,	mIoU: 0.54,	Loss: 411.10
# INFO:root:Step 9 of 140,	Accuracy: 0.82,	mIoU: 0.51,	Loss: 439.86
# INFO:root:Step 14 of 140,	Accuracy: 0.80,	mIoU: 0.54,	Loss: 425.86
# INFO:root:Step 19 of 140,	Accuracy: 0.82,	mIoU: 0.53,	Loss: 421.36
# INFO:root:Step 24 of 140,	Accuracy: 0.81,	mIoU: 0.49,	Loss: 437.87
# INFO:root:Step 29 of 140,	Accuracy: 0.81,	mIoU: 0.50,	Loss: 428.25
# INFO:root:Step 34 of 140,	Accuracy: 0.80,	mIoU: 0.51,	Loss: 430.69
# INFO:root:Step 39 of 140,	Accuracy: 0.80,	mIoU: 0.52,	Loss: 428.57
# INFO:root:Step 44 of 140,	Accuracy: 0.79,	mIoU: 0.50,	Loss: 420.96
# INFO:root:Step 49 of 140,	Accuracy: 0.79,	mIoU: 0.50,	Loss: 424.95
# INFO:root:Step 54 of 140,	Accuracy: 0.79,	mIoU: 0.51,	Loss: 433.76
# INFO:root:Step 59 of 140,	Accuracy: 0.79,	mIoU: 0.52,	Loss: 432.85
# INFO:root:Step 64 of 140,	Accuracy: 0.79,	mIoU: 0.52,	Loss: 433.31
# INFO:root:Step 69 of 140,	Accuracy: 0.80,	mIoU: 0.52,	Loss: 426.36
# INFO:root:Step 74 of 140,	Accuracy: 0.79,	mIoU: 0.53,	Loss: 417.83
# INFO:root:Step 79 of 140,	Accuracy: 0.79,	mIoU: 0.53,	Loss: 419.43
# INFO:root:Step 84 of 140,	Accuracy: 0.79,	mIoU: 0.53,	Loss: 415.36
# INFO:root:Step 89 of 140,	Accuracy: 0.79,	mIoU: 0.53,	Loss: 416.84
# INFO:root:Step 94 of 140,	Accuracy: 0.79,	mIoU: 0.53,	Loss: 414.19
# INFO:root:Step 99 of 140,	Accuracy: 0.79,	mIoU: 0.53,	Loss: 414.70
# INFO:root:Step 104 of 140,	Accuracy: 0.79,	mIoU: 0.53,	Loss: 410.57
# INFO:root:Step 109 of 140,	Accuracy: 0.80,	mIoU: 0.54,	Loss: 409.27
# INFO:root:Step 114 of 140,	Accuracy: 0.80,	mIoU: 0.54,	Loss: 408.17
# INFO:root:Step 119 of 140,	Accuracy: 0.80,	mIoU: 0.54,	Loss: 412.18
# INFO:root:Step 124 of 140,	Accuracy: 0.79,	mIoU: 0.53,	Loss: 413.65
# INFO:root:Step 129 of 140,	Accuracy: 0.80,	mIoU: 0.53,	Loss: 412.51
# INFO:root:Step 134 of 140,	Accuracy: 0.79,	mIoU: 0.54,	Loss: 413.38
# INFO:root:Step 139 of 140,	Accuracy: 0.79,	mIoU: 0.54,	Loss: 414.13
# INFO:root:Validating
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-191ba6fad27d> in <module>
# ----> 1 training_loop()
#
# <ipython-input-12-8bf80e979fd9> in training_loop()
#      20
#      21         logging.info("Validating")
# ---> 22         val_losses, val_accuracies, val_miou = forward_pass(valid_dataloader)
#      23
#      24         logging.info(f"Training accuracy:   {sum(train_accuracies)/len(train_accuracies):.2f} | Training loss: {sum(train_losses)/len(train_losses):.2f} | Training mIoU: {sum(train_miou)/len(train_miou):.2f}")
#
# <ipython-input-13-25e9c80f4855> in forward_pass(dataloader, draw, train)
#      83
#      84         matches = [torch.argmax(i) == j for i, j in zip(label_outputs, clf_labels)]
# ---> 85         acc = matches.count(True)/len(matches)
#      86         iou = bbox_iou(bbox_labels, bbox_outputs)
#      87
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in wrapped(*args, **kwargs)
#      19     assigned = functools.WRAPPER_ASSIGNMENTS
#      20
# ---> 21     @functools.wraps(f, assigned=assigned)
#      22     def wrapped(*args, **kwargs):
#      23         from torch.overrides import has_torch_function, handle_torch_function
#
# KeyboardInterrupt:

# %%
net.load_state_dict(torch.load("best.pth"))
# Out:
# <All keys matched successfully>

# %%
start = time.time()

test_losses, test_accuracies, test_miou = forward_pass(test_dataloader, draw=False, train=False)
total_time = time.time() - start
logging.info(f"Average inference time is: {total_time/len(test_dataloader):.3f}")
logging.info(f"Test accuracy: {sum(test_accuracies)/len(test_accuracies):.2f} | Test loss: {sum(test_losses)/len(test_losses):.2f} | Test mIoU: {sum(test_miou)/len(test_miou):.2f}")
# Out:
# INFO:root:Average inference time is: 0.047
# INFO:root:Test accuracy: 0.83 | Test loss: 455.46 | Test mIoU: 0.58

# %%
INFO:root:Average inference time is: 0.063
INFO:root:Test accuracy: 0.99 | Test loss: 62.80 | Test mIoU: 0.82
# Out:
#   File "<ipython-input-17-ef58aeec6500>", line 1
#     INFO:root:Average inference time is: 0.063
#              ^
# SyntaxError: invalid syntax
